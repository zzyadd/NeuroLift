# %%
import os
import requests
from bs4 import BeautifulSoup
import time

# %%
# 📌 Folder containing files with links
FOLDER_PATH = "/mnt/n/CS/rohana DS/Book from DATLinux"

# %%
# 📌 Folder to save extracted text files
OUTPUT_FOLDER = "/mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
# 📌 Folder containing files with links
FOLDER_PATH = "/mnt/n/CS/rohana DS/Book from DATLinux"

# 📌 Folder to save extracted text files
OUTPUT_FOLDER = "/mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)


def extract_text_from_url(url):
    """Fetches the webpage, waits 30 seconds, then extracts text."""
    print(f"🔗 Opening: {url}")
    time.sleep(30)  # Wait for 30 seconds before scraping

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()  # Raise an error for bad responses (4xx, 5xx)
        soup = BeautifulSoup(response.text, "html.parser")
        return soup.get_text(separator="\n", strip=True)
    except requests.RequestException as e:
        print(f"❌ Error fetching {url}: {e}")
        return ""

def process_folder():
    """Extracts links from HTML files and scrapes the text."""
    for file in os.listdir(FOLDER_PATH):
        if file.endswith(".html") or file.endswith(".htm"):
            file_path = os.path.join(FOLDER_PATH, file)
            book_name = os.path.splitext(file)[0]  # Remove .html extension
            
            with open(file_path, "r", encoding="utf-8") as f:
                soup = BeautifulSoup(f, "html.parser")

            # Extract the first link (modify if multiple links exist)
            link_tag = soup.find("a", href=True)
            if link_tag:
                url = link_tag["href"]
                text = extract_text_from_url(url)

                # Save the extracted text
                output_file = os.path.join(OUTPUT_FOLDER, f"{book_name}.txt")
                with open(output_file, "w", encoding="utf-8") as f:
                    f.write(text)

                print(f"✅ Saved: {output_file}")
            else:
                print(f"⚠ No link found in {file}")
                
                
process_folder()

# %%
process_folder()
# Out:
# 🔗 Opening: http://linear.ups.edu/html/fcla.html
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A First Course in Linear Algebra - Beezer.txt
# 🔗 Opening: https://brouwern.github.io/lbrb/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A Little Book of R for Bioinformatics 2.0 - Avril Coghlan.txt
# 🔗 Opening: https://jakevdp.github.io/WhirlwindTourOfPython/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A Whirlwind Tour of Python - Jake VanderPlas.txt
# 🔗 Opening: https://adv-r.hadley.nz/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Advanced R - Wickham.txt
# 🔗 Opening: https://edwinth.github.io/ADSwR/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Agile Data Science with R - Edwin Thoen.txt
# 🔗 Opening: https://michael-franke.github.io/intro-data-analysis/index.html
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/An Introduction to Data Analysis - Michael Franke.txt
# 🔗 Opening: https://drfloreiche.github.io/index.html
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Analysing Quantitative Data with R - University of Warwick.txt
# 🔗 Opening: https://bookdown.org/pingapang9/linear_models_bookdown/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Analysing_Data_using_Linear_Models__With_applications_in_R_van_den.txt
# 🔗 Opening: https://walker-data.com/census-r/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Analyzing_US_Census_Data__Methods,_Maps,_and_Models_in_R_K_Walker.txt
# 🔗 Opening: https://www.crumplab.com/statistics/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Answering_questions_with_data__Introductory_Statistics_for_Psychology.txt
# 🔗 Opening: https://statswithr.github.io/book/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/An_Introduction_to_Bayesian_Thinking_Clyde,_Çetinkaya_Rundel,_et.txt
# 🔗 Opening: https://earth-env-data-science.github.io/intro.html
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/An_Introduction_to_Earth_and_Environmental_Data_Science_Ryan_Abernathey.txt
# 🔗 Opening: https://paezha.github.io/spatial-analysis-r/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/An_Introduction_to_Spatial_Data_Analysis_and_Statistics__A_Course.txt
# 🔗 Opening: https://www.statlearning.com/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/An_Introduction_to_Statistical_Learning_2ed_James,_Witten,_et_al.txt
# 🔗 Opening: https://book.stat420.org/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Applied Statistics with R - David Dalpiaz.txt
# 🔗 Opening: https://www.causact.com/#welcome
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A_Business_Analyst’s_Introduction_to_Business_Analytics_Fleischhacker.txt
# 🔗 Opening: https://bookdown.org/michael_bcalles/gis-crash-course-in-r/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A_Crash_Course_in_Geographic_Information_Systems_GIS_using_R_Branion.txt
# 🔗 Opening: https://bookdown.org/egarpor/inference/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/A_First_Course_on_Statistical_Inference_Peralta,_García_Portugués.txt
# 🔗 Opening: https://www.bayesrulesbook.com/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Bayes_Rules_An_Introduction_to_Applied_Bayesian_Modeling_Johnson.txt
# 🔗 Opening: https://bookdown.org/roback/bookdown-BeyondMLR/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Beyond Multiple Linear Regression - Roback & Legler.txt
# 🔗 Opening: https://umatter.github.io/BigData/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Big Data Analytics - Ulrich Matter.txt
# 🔗 Opening: https://textbook.coleridgeinitiative.org/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Big Data and Social Science - Foster, Ghani, et al.txt
# 🔗 Opening: https://bookdown.org/yihui/bookdown/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/bookdown__Authoring_Books_and_Technical_Documents_with_R_Markdown.txt
# 🔗 Opening: https://compgenomr.github.io/book/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Computational Genomics with R - Altuna Akalin.txt
# 🔗 Opening: https://inferentialthinking.com/chapters/intro.html
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Computational_and_Inferential_Thinking__The_Foundations_of_Data.txt
# 🔗 Opening: https://dataanalyticsbook.info/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Analytics - A Small Approach - Huang, Deng.txt
# 🔗 Opening: https://cookbook.learndataengineering.com/docs/01-Introduction/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Engineering Cookbook - Andreas Kretz.txt
# 🔗 Opening: https://dataminingbook.info/book_html/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Mining and Machine Learning - Zaki, Meira, et al.txt
# 🔗 Opening: https://bookdown.org/hneth/ds4psy/
# ❌ Error fetching https://bookdown.org/hneth/ds4psy/: HTTPSConnectionPool(host='bookdown.org', port=443): Read timed out. (read timeout=10)
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Science for Psychologists - Hansjörg Neth.txt
# 🔗 Opening: https://bgweber.github.io/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Science for Startups - Ben G Weber.txt
# 🔗 Opening: https://livebook.datascienceheroes.com/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Science Live Book - Pablo Casas.txt
# 🔗 Opening: https://datasciencepractice.study/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Science Practice - Stephenson.txt
# 🔗 Opening: https://rkabacoff.github.io/datavis/
# ❌ Error fetching https://rkabacoff.github.io/datavis/: HTTPSConnectionPool(host='rkabacoff.github.io', port=443): Read timed out. (read timeout=10)
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data Visualization with R - Rob Kabacoff.txt
# 🔗 Opening: https://csmastersuh.github.io/data_analysis_with_python_summer_2021/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data_analysis_with_Python_Summer_2021_University_of_Helsinki.txt
# 🔗 Opening: https://datascienceineducation.com/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data_Science_in_Education_Using_R_Estrellado,_Bovee,_et_al.txt
# 🔗 Opening: https://datasciencejuliahackers.com/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data_Science_in_Julia_for_Hackers_Carrone,_Nicolini,_&_Obst_Demaestri.txt
# 🔗 Opening: https://datasciencebook.ca/
# ❌ Error fetching https://datasciencebook.ca/: HTTPSConnectionPool(host='datasciencebook.ca', port=443): Read timed out. (read timeout=10)
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data_Science__A_First_Introduction_Timbers,_Campbell,_&_Lee.txt
# 🔗 Opening: https://socviz.co/
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Data_Visualization_A_practical_introduction_Kieran_Healy.txt
# 🔗 Opening: https://www.deeplearningbook.org/
# ❌ Error fetching https://www.deeplearningbook.org/: HTTPSConnectionPool(host='www.deeplearningbook.org', port=443): Read timed out. (read timeout=10)
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Deep Learning - Goodfellow, Bengio, & Courville.txt
# 🔗 Opening: https://datasciencedesign.com/
# ❌ Error fetching https://datasciencedesign.com/: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ✅ Saved: /mnt/c/Users/Zy565/Downloads/m4ro3_t5rg/dataForProject/Designing and Building Data Science Solutions - Van Otten.txt
# 🔗 Opening: https://d2l.ai/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 process_folder()
#
# Cell In[43], line 29, in process_folder()
#      27 if link_tag:
#      28     url = link_tag["href"]
# ---> 29     text = extract_text_from_url(url)
#      31     # Save the extracted text
#      32     output_file = os.path.join(OUTPUT_FOLDER, f"{book_name}.txt")
#
# Cell In[43], line 4, in extract_text_from_url(url)
#       2 """Fetches the webpage, waits 30 seconds, then extracts text."""
#       3 print(f"🔗 Opening: {url}")
# ----> 4 time.sleep(30)  # Wait for 30 seconds before scraping
#       6 try:
#       7     response = requests.get(url, timeout=10)
#
# KeyboardInterrupt:
