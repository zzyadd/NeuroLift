# %%
import os
import shutil
import multiprocessing

# Source and target directories
source_folder = r"/mnt/n/New folder"
target_folder = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random"

# Allowed file extensions (caption/subtitle files)
cc_extensions = {".txt", ".vtt", ".srt", ".sub", ".ass", ".dfxp", ".sbv"}

# Function to process and copy a file
def process_file(file_info):
    file_path, relative_path = file_info  # Unpack tuple
    target_path = os.path.join(target_folder, relative_path)  # Recreate original structure
    
    os.makedirs(os.path.dirname(target_path), exist_ok=True)  # Ensure parent folders exist
    try:
        shutil.copy2(file_path, target_path)  # Copy file
        print(f"Copied: {file_path} → {target_path}")
    except Exception as e:
        print(f"Error copying {file_path}: {e}")

if __name__ == "__main__":
    # Collect all matching files
    files_to_copy = []
    for root, _, files in os.walk(source_folder):
        for file in files:
            if os.path.splitext(file)[1].lower() in cc_extensions:  # Check file extension
                full_path = os.path.join(root, file)
                relative_path = os.path.relpath(full_path, source_folder)  # Preserve structure
                files_to_copy.append((full_path, relative_path))  # Store (full_path, relative_path)

    # Use multiprocessing to speed up the copying process
    num_workers = min(multiprocessing.cpu_count(), len(files_to_copy))  # Optimize worker count
    with multiprocessing.Pool(processes=num_workers) as pool:
        pool.map(process_file, files_to_copy)
# Out:
# Copied: /mnt/n/New folder/Assignment Question_1.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/Assignment Question_1.txtCopied: /mnt/n/New folder/BigDataMardeen2.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/BigDataMardeen2.txt
#
# Copied: /mnt/n/New folder/sol.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/sol.txt
# Copied: /mnt/n/New folder/json Flattener.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/json Flattener.txt
# Copied: /mnt/n/New folder/spark-log.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/spark-log.txtCopied: /mnt/n/New folder/NIFTY_F1.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/NIFTY_F1.txt
#
# Copied: /mnt/n/New folder/README.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/README.txt
# Copied: /mnt/n/New folder/0. Introduction/01. Leverage generative AI for analytics and insights.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction/01. Leverage generative AI for analytics and insights.srtCopied: /mnt/n/New folder/0. Introduction/03. How to use the challenge exercise files.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction/03. How to use the challenge exercise files.srt
#
# Copied: /mnt/n/New folder/0. Introduction/02. What you should know.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction/02. What you should know.srt
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/03. Raw data is messy.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data/03. Raw data is messy.srt
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/04. Role of data in the machine learning workflow.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data/04. Role of data in the machine learning workflow.srt
# Copied: /mnt/n/New folder/2. Understanding Data/01. Data with a structure.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/01. Data with a structure.srtCopied: /mnt/n/New folder/2. Understanding Data/04. Python for data preprocessing with Pandas and Matplotlib.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/04. Python for data preprocessing with Pandas and Matplotlib.srtCopied: /mnt/n/New folder/1. Why Process and Why Visualize Data/02. Our use case.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data/02. Our use case.srt
#
# Copied: /mnt/n/New folder/2. Understanding Data/02. Data without a structure.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/02. Data without a structure.srt
#
# Copied: /mnt/n/New folder/2. Understanding Data/03. Using simple Python code to check your data.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/03. Using simple Python code to check your data.srt
# Copied: /mnt/n/New folder/2. Understanding Data/05. Challenge Load and check the data using Python.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/05. Challenge Load and check the data using Python.srt
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/01. We live in a data-driven world!.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data/01. We live in a data-driven world!.srtCopied: /mnt/n/New folder/3. Data Preprocessing/01. Data preprocessing the telecom dataset.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing/01. Data preprocessing the telecom dataset.srt
#
# Copied: /mnt/n/New folder/2. Understanding Data/06. Solution Load and check the data using Python.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data/06. Solution Load and check the data using Python.srtCopied: /mnt/n/New folder/3. Data Preprocessing/02. Introduction to text preprocessing.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing/02. Introduction to text preprocessing.srt
#
# Copied: /mnt/n/New folder/3. Data Preprocessing/04. Solution Data preprocessing the telecom dataset.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing/04. Solution Data preprocessing the telecom dataset.srt
# Copied: /mnt/n/New folder/3. Data Preprocessing/03. Challenge Data preprocessing the telecom dataset.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing/03. Challenge Data preprocessing the telecom dataset.srt
# Copied: /mnt/n/New folder/4. Exploratory Data Analysis/02. Challenge Perform exploratory data analysis.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis/02. Challenge Perform exploratory data analysis.srtCopied: /mnt/n/New folder/4. Exploratory Data Analysis/01. Exploratory data analysis EDA.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis/01. Exploratory data analysis EDA.srt
#
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/03. Generative modeling use cases.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI/03. Generative modeling use cases.srt
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/02. What is deep learning.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI/02. What is deep learning.srtCopied: /mnt/n/New folder/5. Predictive and Generative AI/01. Overview of predictive and generative AI.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI/01. Overview of predictive and generative AI.srtCopied: /mnt/n/New folder/5. Predictive and Generative AI/04. Predictive modeling use cases.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI/04. Predictive modeling use cases.srt
# Copied: /mnt/n/New folder/4. Exploratory Data Analysis/03. Solution Perform exploratory data analysis.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis/03. Solution Perform exploratory data analysis.srt
#
#
# Copied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/01. Deep learning Predict customer lifetime value.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model/01. Deep learning Predict customer lifetime value.srt
# Copied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/03. Solution Predict customer lifetime value.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model/03. Solution Predict customer lifetime value.srtCopied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/02. Challenge Predict customer lifetime value.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model/02. Challenge Predict customer lifetime value.srt
#
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/05. Solution Generate sentiments using BERT.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model/05. Solution Generate sentiments using BERT.srtCopied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/01. Introduction to capstone and use case.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model/01. Introduction to capstone and use case.srtCopied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/03. Solution Predict media channel sales using Keras.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model/03. Solution Predict media channel sales using Keras.srtCopied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/02. Challenge Predict media channel sales using Keras.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model/02. Challenge Predict media channel sales using Keras.srt
#
#
#
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/04. Optional challenge Generate sentiments using BERT.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model/04. Optional challenge Generate sentiments using BERT.srt
# Copied: /mnt/n/New folder/8. Conclusion/01. Next steps.srt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/8. Conclusion/01. Next steps.srt
# Copied: /mnt/n/New folder/intro to social/CA-AstroPh.txt → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/intro to social/CA-AstroPh.txt

# %%
import os
import shutil
import concurrent.futures

# Source folder
source_folder = r"/mnt/n/New folder"

# Target folders
target_subtitles = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random"
target_pdfs = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/pdf"

# Ensure target directories exist
os.makedirs(target_subtitles, exist_ok=True)
os.makedirs(target_pdfs, exist_ok=True)

# File extensions to search for
subtitle_extensions = {".srt", ".vtt", ".txt", ".sub", ".ass", ".ssa"}  # Common subtitle file types
pdf_extension = ".pdf"

def copy_file(file_path, dest_folder, parent_structure=False):
    """Copy file to destination, optionally preserving parent folder structure."""
    try:
        if parent_structure:
            relative_path = os.path.relpath(os.path.dirname(file_path), source_folder)
            target_path = os.path.join(dest_folder, relative_path)
            os.makedirs(target_path, exist_ok=True)
        else:
            target_path = dest_folder
        
        shutil.copy(file_path, target_path)
        print(f"Copied: {file_path} -> {target_path}")
    except Exception as e:
        print(f"Error copying {file_path}: {e}")

def process_file(file_path):
    """Determine if a file should be copied and where."""
    _, ext = os.path.splitext(file_path)
    ext = ext.lower()
    
    if ext in subtitle_extensions:
        copy_file(file_path, target_subtitles, parent_structure=True)
    elif ext == pdf_extension:
        copy_file(file_path, target_pdfs, parent_structure=False)

def scan_and_copy():
    """Scan all files in the source folder and copy them accordingly."""
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        for root, _, files in os.walk(source_folder):
            for file in files:
                file_path = os.path.join(root, file)
                executor.submit(process_file, file_path)

if __name__ == "__main__":
    scan_and_copy()
# Out:
# Copied: /mnt/n/New folder/Assignment Question_1.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/BigDataMardeen2.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/README.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/sol.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/NIFTY_F1.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/json Flattener.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/spark-log.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/.
# Copied: /mnt/n/New folder/0. Introduction/01. Leverage generative AI for analytics and insights.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction
# Copied: /mnt/n/New folder/0. Introduction/03. How to use the challenge exercise files.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/01. We live in a data-driven world!.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/02. Our use case.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data
# Copied: /mnt/n/New folder/0. Introduction/02. What you should know.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/0. Introduction
# Copied: /mnt/n/New folder/3. Data Preprocessing/01. Data preprocessing the telecom dataset.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing
# Copied: /mnt/n/New folder/4. Exploratory Data Analysis/03. Solution Perform exploratory data analysis.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis
# Copied: /mnt/n/New folder/2. Understanding Data/05. Challenge Load and check the data using Python.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/2. Understanding Data/03. Using simple Python code to check your data.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/2. Understanding Data/04. Python for data preprocessing with Pandas and Matplotlib.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/3. Data Preprocessing/03. Challenge Data preprocessing the telecom dataset.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing
# Copied: /mnt/n/New folder/2. Understanding Data/06. Solution Load and check the data using Python.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/03. Raw data is messy.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data
# Copied: /mnt/n/New folder/4. Exploratory Data Analysis/01. Exploratory data analysis EDA.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis
# Copied: /mnt/n/New folder/3. Data Preprocessing/04. Solution Data preprocessing the telecom dataset.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing
# Copied: /mnt/n/New folder/2. Understanding Data/01. Data with a structure.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/1. Why Process and Why Visualize Data/04. Role of data in the machine learning workflow.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/1. Why Process and Why Visualize Data
# Copied: /mnt/n/New folder/4. Exploratory Data Analysis/02. Challenge Perform exploratory data analysis.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/4. Exploratory Data Analysis
# Copied: /mnt/n/New folder/3. Data Preprocessing/02. Introduction to text preprocessing.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/3. Data Preprocessing
# Copied: /mnt/n/New folder/2. Understanding Data/02. Data without a structure.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/2. Understanding Data
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/02. What is deep learning.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/01. Overview of predictive and generative AI.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/04. Predictive modeling use cases.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI
# Copied: /mnt/n/New folder/5. Predictive and Generative AI/03. Generative modeling use cases.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/5. Predictive and Generative AI
# Copied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/02. Challenge Predict customer lifetime value.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model
# Copied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/01. Deep learning Predict customer lifetime value.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model
# Copied: /mnt/n/New folder/6. Deep Learning Build and Evaluate a Predictive Model/03. Solution Predict customer lifetime value.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/6. Deep Learning Build and Evaluate a Predictive Model
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/01. Introduction to capstone and use case.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/02. Challenge Predict media channel sales using Keras.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/04. Optional challenge Generate sentiments using BERT.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model
# Copied: /mnt/n/New folder/8. Conclusion/01. Next steps.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/8. Conclusion
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/03. Solution Predict media channel sales using Keras.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model
# Copied: /mnt/n/New folder/7. Capstone Build and Evaluate a Predictive and Generative Model/05. Solution Generate sentiments using BERT.srt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/7. Capstone Build and Evaluate a Predictive and Generative Model
# Copied: /mnt/n/New folder/intro to social/CA-AstroPh.txt -> /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/random/intro to social
