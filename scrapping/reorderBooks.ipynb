# %%
import os
import shutil
import fitz  # PyMuPDF
import concurrent.futures

# Define folder paths
folder1 = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS"
folder2 = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/less_than_200_pages"

# Ensure destination folder exists
os.makedirs(folder2, exist_ok=True)

# Function to process a single PDF
def process_pdf(filename):
    if not filename.lower().endswith(".pdf"):
        return  # Skip non-PDF files

    file_path = os.path.join(folder1, filename)

    try:
        # Open PDF and count pages
        with fitz.open(file_path) as doc:
            num_pages = len(doc)

        # Move PDF if it has less than 10 pages
        if num_pages < 200:
            shutil.move(file_path, os.path.join(folder2, filename))
            print(f"Moved: {filename} ({num_pages} pages)")
    
    except Exception as e:
        print(f"Error processing {filename}: {e}")

# Get all PDF files
pdf_files = [f for f in os.listdir(folder1) if f.lower().endswith(".pdf")]

# Use ThreadPoolExecutor to process PDFs in parallel
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    executor.map(process_pdf, pdf_files)
# Out:
# Moved: 004_AllCourseSlides.pdf (192 pages)
# Moved: 150__Python_Pattern_Programs__2024_.pdf (199 pages)
# Moved: 120_Advanced_JavaScript_Interview_Questi.pdf (143 pages)
# Moved: 150__JavaScript_Pattern_Programs.pdf (184 pages)
# Moved: 100_SQL_Server_Mistakes_and_How_to_Avoid.pdf (131 pages)
# Moved: 001_365_Data_Science_Data_Science_Interv.pdf (111 pages)
# Moved: 2_HCIA_AI_V3_0_Lab_Guide.pdf (169 pages)
# Moved: 2014_Book_ThePythonWorkbook.pdf (169 pages)
# Moved: 501_Challenging_Logic_and_Reasoning_Prob.pdf (160 pages)
# Moved: 100_Page_Python_Intro.pdf (117 pages)
# Moved: Abella_Hernando_120_Advanced_Python_Inte.pdf (131 pages)
# Moved: 50_Python_Concepts_Every_Developer_Shoul_1.pdf (182 pages)
# Moved: 3___Advanced_MySQL_Analysis.pdf (180 pages)
# Moved: 11_1_gpt_4.pdf (100 pages)
# Moved: 005_PL_300_Exam_Prep.pdf (165 pages)
# Moved: 80__Python_Coding_Challenges_for_Beginne.pdf (128 pages)
# Moved: 190__Python_Interview_Questions_and_Answ.pdf (192 pages)
# Moved: Ai7ba57.pdf (132 pages)
# Moved: 5_6111648495528050862.pdf (118 pages)
# Moved: abdallah_samy.pdf (121 pages)
# Moved: 5_6152196684769133702.pdf (100 pages)
# Moved: Adam_Stewart__Python_Programming___Pytho.pdf (115 pages)
# Moved: Advanced_Web_Development_With_React__202.pdf (196 pages)
# Moved: 50_Python_Concepts_Every_Developer_Shoul.pdf (191 pages)
# Moved: 501_challenging_logic_reasoning_2e_pdf__.pdf (160 pages)
# Moved: 2_1_slides.pdf (184 pages)
# Moved: ARA_NMDVBARJ_1_128_170421_0.pdf (143 pages)
# Moved: An_Introduction_to_Statistical_Learning_.pdf (121 pages)
# Moved: Advanced_Image_Processing_with_Python_an.pdf (123 pages)
# Moved: A_Primer_to_the_42_Most_commonly_used_Ma.pdf (192 pages)
# Moved: Big_Data__Interview_questtions_.pdf (189 pages)
# Moved: AI_for_Beginners_Made_Easy.pdf (186 pages)
# Moved: ARA_NMDVBARJ_1_128_170421_0__2_.pdf (143 pages)
# Moved: A_Simple_Introduction_to_Python.pdf (113 pages)
# Moved: All_course_slides.pdf (192 pages)
# Moved: Christina_Maher.pdf (159 pages)
# Moved: Black_Hat_Bash.pdf (132 pages)
# Moved: andrew_ng_machine_learning_yearning.pdf (118 pages)
# Moved: byte_of_python.pdf (117 pages)
# Moved: ByteByteGo___The_Big_Archive.pdf (159 pages)
# Moved: all_in_one_cheat_sheet_v2_6_web.pdf (191 pages)
# Moved: Coding_for_Absolute_Beginners.pdf (176 pages)
# Moved: BIG_DATA_HADOOP_AND_JAVA_CODING_MADE_SIM.pdf (188 pages)
# Moved: CBAPa7432.pdf (106 pages)
# Moved: AWS___machinelearning.pdf (145 pages)
# Moved: Bootstrap_for_ASP_NET_MVC.pdf (198 pages)
# Moved: Basics_of_Image_Processing.pdf (169 pages)
# Moved: datascienceM_Exploring_Deepfakes__2023_.pdf (192 pages)
# Moved: Creating_Good_Data.pdf (112 pages)
# Moved: Complete_Guide_to_Python_Programming.pdf (114 pages)
# Moved: A_Course_in_Machine_Learning.pdf (189 pages)
# Moved: Coffee_Break_Python.pdf (199 pages)
# Moved: C___How_to_Program__An_Objects.pdf (176 pages)
# Moved: Creating_a_Database___Part_I.pdf (113 pages)
# Moved: DEEP_LEARNING.pdf (100 pages)
# Moved: CompVisNotes.pdf (115 pages)
# Moved: Coding_JavaScript__2024_.pdf (132 pages)
# Moved: Data_Analytics_for_Discourse_Analysis_wi.pdf (190 pages)
# Moved: Data_Engineering_Made_Simple.pdf (121 pages)
# Moved: ARA_NMDVBARJ_1_128_170421_0__1_.pdf (143 pages)
# Moved: Deep_Learning_with_Scikit_learn_and_PyTo.pdf (126 pages)
# Moved: Data_Structure___Algorithm_.pdf (126 pages)
# Moved: Data_Visualization_Grossberg_lecture1.pdf (172 pages)
# Moved: Data_Scientist_Interview_Questions.pdf (111 pages)
# Moved: Exploring_University_Mathematics_with_Py.pdf (100 pages)
# Moved: Deep_Learning_Networks.pdf (173 pages)
# Moved: Demand_Forecasting_for_Inventory_Control.pdf (188 pages)
# Moved: datascienceM_Python_Programming_and_SQL.pdf (152 pages)
# Moved: Exception_Handling.pdf (120 pages)
# Moved: Deep_Learning___.pdf (104 pages)
# Moved: Forecasting__Principles___Practice___Rob.pdf (138 pages)
# Moved: HCIA_Cloud_Computing_V4_0_Lab_Guide.pdf (133 pages)
# Moved: gisbook.pdf (138 pages)
# Moved: HCIA_Big_Data_V3_5_Lab_Guide.pdf (183 pages)
# Moved: ENG_NMDVBARJ_1_128_170421_0.pdf (143 pages)
# Moved: Delta_Lake_Series_.pdf (105 pages)
# Moved: GUI_Programming_with_Python.pdf (113 pages)
# Moved: gpt_4.pdf (100 pages)
# Moved: GitNotesForProfessionals.pdf (195 pages)
# Moved: HCIA_Cloud_Computing_V4_0_Learning_Guide.pdf (142 pages)
# Moved: Grokking_the_Java_Interview.pdf (159 pages)
# Moved: Introduction_to_Data_Science.pdf (196 pages)
# Moved: Executive_Data_Science.pdf (153 pages)
# Moved: HCIA_Cloud_Computing_V4_0_Training_Mater.pdf (192 pages)
# Moved: HCIA_Storage_V4_5_Lab_Guide.pdf (176 pages)
# Moved: Illuminating_the_Path__The_R_D_Agenda_fo.pdf (190 pages)
# Moved: High_Performance_Spark.pdf (105 pages)
# Moved: interviews.pdf (169 pages)
# Moved: Introduction_to_Arabic_Natural_Language_.pdf (186 pages)
# Moved: How_to_Lie_with_Statistics.pdf (141 pages)
# Moved: How_to_program_in_PYTHON.pdf (135 pages)
# Moved: HCIA_Cloud_Service_V3_0_Learning_Guide.pdf (180 pages)
# Moved: Introduction_to_JOINs.pdf (174 pages)
# Moved: interpretable_machine_learning_the_fuss_.pdf (125 pages)
# Moved: Learn_PowerShell_Scripting_in_a_Month_of.pdf (151 pages)
# Moved: Lessons_from_Large_Scale_Machine_Learnin.pdf (105 pages)
# Moved: Learning_Advanced_Python_by_Studying_Ope.pdf (139 pages)
# Moved: Introduction_to_Regular_Expressions_in_S.pdf (120 pages)
# Moved: Learning_DevSecOps.pdf (195 pages)
# Moved: Machine_Learning_Concepts_from_A_to_Z.pdf (114 pages)
# Moved: Learn_Python_Fast_Deep_Simple.pdf (147 pages)
# Moved: machine_learning_cheat_sheet.pdf (135 pages)
# Moved: Machine_Learning_in_Action______.pdf (148 pages)
# Moved: Learning_NumPy_Array.pdf (164 pages)
# Moved: Learning_scikit_learn___Machine_Learning.pdf (118 pages)
# Moved: Java_Cheat_Sheet.pdf (163 pages)
# Moved: Introduction_to_Stored_Routines.pdf (111 pages)
# Moved: Lecture_notes_for_the_Statistical_Machin.pdf (112 pages)
# Moved: Leetcode_SQL_questions.pdf (122 pages)
# Moved: Machine_Learning_is_Fun.pdf (142 pages)
# Moved: Looks_Good_to_Me__2023_.pdf (181 pages)
# Moved: Machine_Learning_Mastery_with_Python.pdf (179 pages)
# Moved: ITI_Communication_Skills.pdf (160 pages)
# Moved: LeetCode_SQL_Questions_With_Solutions.pdf (105 pages)
# Moved: LLMs_in_Production__2023_.pdf (160 pages)
# Moved: Linear_Regression_With_Python.pdf (140 pages)
# Moved: Machine_Learning_Methods_for_Multi_Omics.pdf (171 pages)
# Moved: Maths_for_AI.pdf (176 pages)
# Moved: mcit_Day_1.pdf (128 pages)
# Moved: Machine_Learning_With_Python.pdf (137 pages)
# Moved: Mastering_Pandas__Advanced_Pandas_for_Fi.pdf (150 pages)
# Moved: machine_learning_yearning.pdf (118 pages)
# Moved: Mastering_Python_Programming.pdf (197 pages)
# Moved: ML_and_Data_Mining_Notes.pdf (126 pages)
# Moved: Mastering_DevOps_Interviews.pdf (147 pages)
# Moved: Mohamed_Elsayed.pdf (174 pages)
# Moved: Machine_Learning_with_Python__2024_.pdf (147 pages)
# Moved: Machine_Learning_Yearing_by_Andrew_Ng.pdf (118 pages)
# Moved: More_than_a_Chatbot.pdf (133 pages)
# Moved: Machine_Learning_Using_C__Succinctly.pdf (148 pages)
# Moved: Master_Machine_Learning_Algorithm.pdf (163 pages)
# Moved: ML_God.pdf (104 pages)
# Moved: Mastering_Mojo_Programming.pdf (102 pages)
# Moved: OpenAI_Developer_s_Handbook.pdf (132 pages)
# Moved: MYSQL_Guide_for_Beginner.pdf (118 pages)
# Moved: Node_js_Web_Development_For_Beginners__2.pdf (156 pages)
# Moved: Ng_MLY01_13.pdf (118 pages)
# Moved: MASTERING_PYTHON_FOR_DATA_SCIENCE_WITH_N.pdf (136 pages)
# Moved: Mastering_Python.pdf (166 pages)
# Moved: Object_Oriented_Programming_Exercises_wi.pdf (141 pages)
# Moved: Neural_Networks_Using_C__Succinctly.pdf (128 pages)
# Moved: Nichola_Lacey__Python_by_Example__Learni.pdf (191 pages)
# Moved: powerpivot.pdf (115 pages)
# Moved: Openai_Api_Cookbook.pdf (187 pages)
# Moved: o_Scott_Murray_Interactive_Data_Visualiz.pdf (186 pages)
# Moved: Object_Oriented_Programming.pdf (139 pages)
# Moved: Practical_Python_and_OpenCV.pdf (166 pages)
# Moved: NoSQL_Databases.pdf (141 pages)
# Moved: OPENCV___Python_for_Computer_Vision.pdf (167 pages)
# Moved: Microsoft_Press_ebook_Introducing_Power_.pdf (189 pages)
# Moved: Python_Cheat_Sheet__2_.pdf (171 pages)
# Moved: Portable_Python_Projects__2022_.pdf (176 pages)
# Moved: nli_tutorial.pdf (181 pages)
# Moved: Python_for_Data_Science__2_.pdf (112 pages)
# Moved: Python_Machine_Learning_Cookbook___Early.pdf (170 pages)
# Moved: Python_for_Beginners.pdf (115 pages)
# Moved: Python_Exercises_with_Data_Structures_an.pdf (104 pages)
# Moved: Python_Logging.pdf (127 pages)
# Moved: Python_for_Information_Professionals__20.pdf (173 pages)
# Moved: Practical_Weak_Supervision.pdf (193 pages)
# Moved: Python_Handwritten_Notes__2023_.pdf (186 pages)
# Moved: Python_Machine_Learning_Projects.pdf (135 pages)
# Moved: Python_GUI_Automation_for_Beginners.pdf (126 pages)
# Moved: Python_Playground.pdf (101 pages)
# Moved: Python_Advanced_Programming.pdf (185 pages)
# Moved: Python_for_Data_Analysis.pdf (128 pages)
# Moved: Python_for_OSINT.pdf (137 pages)Moved: Python_Programming_for_Beginners_Crash_C.pdf (169 pages)
# Moved: Python_Programming_Handbook_For_GUI_Deve.pdf (148 pages)
# Moved: Python_Machine_Learning__2024_.pdf (132 pages)
#
# Moved: Python_Programming_for_Beginners__2023_.pdf (185 pages)
# Moved: Python_Programming_Handbook_For_IoT_Deve.pdf (139 pages)
# Moved: Python___Pandas___Beginner_to_Intermedia.pdf (115 pages)
# Moved: Python_programming_workbook_for_blockcha.pdf (101 pages)
# Moved: Python_Programming_Basics.pdf (145 pages)
# Moved: Python_Machine_Learning__3_.pdf (111 pages)
# Moved: Python_Programming_Workbook_for_Web_Scra.pdf (197 pages)
# Moved: Relational_schemas___Primary_key.pdf (135 pages)
# Moved: Retail_Analytics__Integrated_Forecasting.pdf (126 pages)
# Moved: Quantum_AI___Machine_Learning_and_Deep_L.pdf (119 pages)
# Moved: Python_programming_workbook_for_machine_.pdf (149 pages)
# Moved: regmods.pdf (144 pages)
# Moved: Self_Supervised_Learning.pdf (122 pages)
# Moved: Robust_Machine_Learning.pdf (180 pages)
# Moved: Python_Tips_and_Tricks.pdf (122 pages)
# Moved: rprogramming.pdf (184 pages)
# Moved: Python_Programming_Handbook_For_Robotics.pdf (124 pages)
# Moved: Senior_Project_Documentation_pdf.pdf (183 pages)
# Moved: Session3.pdf (107 pages)
# Moved: Session1.pdf (100 pages)
# Moved: Real_Time_Database_Systems.pdf (126 pages)
# Moved: Reinforcement_Learning___With_Open_AI__T.pdf (174 pages)
# Moved: ScalaByExample.pdf (145 pages)
# Moved: Solve_Any_Data_Analysis_Problem.pdf (135 pages)
# Moved: Recurrent_Neural_Networks__2016_.pdf (139 pages)
# Moved: R_Programming_Print_version.pdf (169 pages)
# Moved: SELECT___FROM.pdf (129 pages)
# Moved: SQL_and_NoSQL_Interview_Questions__2023_.pdf (195 pages)
# Moved: Sql_Basics_And_Advanced.pdf (101 pages)
# Moved: SMM_Slides_ch2.pdf (107 pages)
# Moved: State_of_AI_Report_2022___ONLINE.pdf (114 pages)
# Moved: Text_Mining_with_R.pdf (184 pages)
# Moved: SQL__68_Things_Beginners_Need_to_Know.pdf (162 pages)
# Moved: SQL_Theory.pdf (133 pages)
# Moved: The_Orange_Book_of_Machine_Learning.pdf (135 pages)
# Moved: SQL_QuickStart_Guide.pdf (150 pages)
# Moved: statistical_inference_in_data_science.pdf (124 pages)
# Moved: Supervised_Machine_Learning.pdf (112 pages)
# Moved: The_Little_Book_of_Deep_Learning.pdf (167 pages)
# Moved: TensorFlow_Guide.pdf (130 pages)
# Moved: Thinking_in_Pandas.pdf (190 pages)
# Moved: The_1_Page_Python_Book.pdf (148 pages)
# Moved: The_Execative_Guide_to_AI_v2020.pdf (104 pages)
# Moved: The_Decision_Maker_s_Handbook_to_Data_Sc.pdf (189 pages)
# Moved: Tidy_First.pdf (125 pages)
# Moved: theobald_oliver_machine_learning_for_abs.pdf (179 pages)
# Moved: Types_of_MySQL_Variables___Local_Variabl.pdf (117 pages)
# Moved: The_Python_Bible_for_Beginners.pdf (189 pages)
# Moved: Twisted_Python_Projects.pdf (137 pages)
# Moved: SQL__Questions_with_Answers.pdf (105 pages)
# Moved: Unlocking_the_Code.pdf (154 pages)
# Moved: week20.pdf (102 pages)
# Moved: Understanding_Large_Language_Models.pdf (145 pages)
# Moved: xgboost_extreme_gradient_boosting.pdf (128 pages)
# Moved: إدارة مشاريع عملي.pdf (105 pages)
# Moved: The_Python_Advantage.pdf (177 pages)
# Moved: Zefs_Guide_to_Deep_Learning.pdf (163 pages)
# Moved: الذكاء الاصطناعي خطوة بخطوة.pdf (173 pages)
# Moved: التعلم العميق Deep learning.pdf (192 pages)
# Moved: Using_Python_to_Develop_Analytics__Contr.pdf (109 pages)
# Moved: The_Ultimate_Guide_to_PYTHON_CERTIFICATI.pdf (134 pages)
# Moved: Tkinter_GUI_Projects_with_Python.pdf (168 pages)
# Moved: The_Python_Bible_for_Beginners__2024_.pdf (155 pages)
# Moved: الرسم الفنى للهندسة الميكانيكية.pdf (151 pages)
# Moved: مدخل إلى عالم الذكاء الاصطناعي.pdf (101 pages)
# Moved: موسوعة البرمجة بلغة ال C++.pdf (101 pages)
# Moved: دروس في مجال الذكاء الاصطناعي.pdf (150 pages)
# Moved: كتاب عن لغة c++.pdf (122 pages)
# Moved: كتاب دليل سريع في لغة الـ c++.pdf (198 pages)

# %%
import os
import shutil
import fitz  # PyMuPDF
import pdfplumber  # Alternative PDF parser
import multiprocessing

# Define folder paths
folder1 = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS"
folder2 = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/more_than_100_pages"

# Ensure destination folder exists
os.makedirs(folder2, exist_ok=True)

# Function to process a single PDF
def process_pdf(filename):
    file_path = os.path.join(folder1, filename)

    if not filename.lower().endswith(".pdf") or not os.path.isfile(file_path):
        print(f"Skipping (not found or invalid): {filename}")
        return

    num_pages = 0  # Default value in case of an error

    # Attempt to read using PyMuPDF
    try:
        with fitz.open(file_path) as doc:
            num_pages = len(doc)
    except Exception as e:
        print(f"Error with PyMuPDF: {filename} - {e}")
        # Try using pdfplumber as a backup
        try:
            with pdfplumber.open(file_path) as pdf:
                num_pages = len(pdf.pages)
        except Exception as e2:
            print(f"Skipping (unreadable): {filename} - {e2}")
            return  # Skip unreadable files

    # Move PDF if it has more than 500 pages
    if num_pages > 500:
        shutil.move(file_path, os.path.join(folder2, filename))
        print(f"Moved: {filename} ({num_pages} pages)")

if __name__ == "__main__":
    # Get all PDF files
    pdf_files = [f for f in os.listdir(folder1) if f.lower().endswith(".pdf")]

    # Use multiprocessing Pool for parallel execution
    num_workers = min(multiprocessing.cpu_count(), len(pdf_files))  # Max cores or file count
    with multiprocessing.Pool(processes=num_workers) as pool:
        pool.map(process_pdf, pdf_files)
# Out:
# Moved: 003_All_slides.pdf (626 pages)
# Moved: Daily_Dose_Of_Data_Science_Full_Archive.pdf (531 pages)
# Moved: Algorithms_for_image_processing_and_comp.pdf (506 pages)
# Moved: Begin_to_Code.pdf (595 pages)
# Moved: Coding_Games_in_Scratch.pdf (676 pages)
# Moved: Architecting_for_Scale.pdf (507 pages)
# Moved: 1111534128.pdf (530 pages)
# Moved: Advanced_Data_Mining_and_Applications.pdf (848 pages)
# Moved: 2_Practical_Data_Science.pdf (821 pages)
# Moved: Database_System_Concepts.pdf (1373 pages)
# Moved: Better_Python_Code__2_.pdf (841 pages)
# Moved: Cracking_Coding_Interview.pdf (712 pages)
# Moved: Database_System_Concepts_etc_.pdf (1519 pages)
# Moved: DataFrame_Manipulation__2024_.pdf (696 pages)
# Moved: 15_Math_Concepts_Every_Data_Scientist_Sh.pdf (577 pages)
# Moved: Beyond_AI.pdf (532 pages)
# Moved: Cracking_the_Coding_Interview__6th_Editi.pdf (712 pages)
# Moved: A_Course_in_Natural_Language_Processing.pdf (543 pages)
# Moved: Cracking_the_Coding_Interview__6th_Editi_1.pdf (712 pages)
# Moved: Arduino_for_Arduinians.pdf (633 pages)
# Moved: Computer_Basics_Absolute_Beginner_s_Guid.pdf (547 pages)
# Moved: 1_HCIP_AI_EI_Developer_V2_0_Training_Mat.pdf (508 pages)
# Moved: Advanced_Python_Automation.pdf (504 pages)
# Moved: Build_your_own_Programming_Language.pdf (759 pages)
# Moved: A_Journey_to_Core_Python__datascienceM.pdf (693 pages)
# Moved: Cybersecurity_All_in_One_For_Dummies.pdf (726 pages)
# Moved: Arduino_Workshop.pdf (891 pages)
# Moved: Andrew_S__Tanenbaum___Modern_Operating_S.pdf (1137 pages)
# Moved: datascienceM_Building_Statistical_Models.pdf (656 pages)
# Moved: Arnold_Robbins__Elbert_Hannah_Learning_t.pdf (548 pages)
# Moved: Advances_in_Computational_Vision_and_Rob.pdf (549 pages)
# Moved: A_Tour_of_C____2024_.pdf (1095 pages)
# Moved: Big_Data_and_Hadoop.pdf (628 pages)
# Moved: 2009_Book_TheElementsOfStatisticalLearni.pdf (757 pages)
# Moved: Bash_Cookbook_O_Reilly_Media__2017_.pdf (725 pages)
# Moved: Angular_Cookbook.pdf (644 pages)
# Moved: datascienceM_Designing_Deep_Learning_Sys.pdf (543 pages)
# Moved: Data_Analytics___Visualization_All_in_On.pdf (835 pages)
# Moved: Artificial_Intelligence_Programming_with.pdf (716 pages)
# Moved: C__12_and__NET_8.pdf (1098 pages)
# Moved: Data_Cleaning_with_Power_BI__2024_.pdf (620 pages)
# Moved: 2017_Martin_Kleppmann_Designing_Data_Int.pdf (613 pages)
# Moved: Agile_Principles_Patterns_and_Practices_.pdf (944 pages)
# Moved: C__20.pdf (678 pages)
# Moved: Data_Communication_and_Computer_Networks.pdf (513 pages)
# Moved: Absolute_Beginner_s_Guide_to_Algorithms.pdf (563 pages)
# Moved: Computer_Vision_by_Richard_Szeliski.pdf (1232 pages)
# Moved: AI_Assisted_Programming_for_Web_and_Mach.pdf (720 pages)
# Moved: Data_Driven_Science_and_Engineering.pdf (615 pages)
# Moved: datascienceM_Software_Architecture_with_.pdf (620 pages)
# Moved: C__and_Algorithmic_Thinking_for_the_Comp.pdf (942 pages)
# Moved: CCNA_200_301_Official_Cert_Guide_Volume_.pdf (1095 pages)
# Moved: Bayesian_Reasoning_and_Machine_Learning.pdf (690 pages)
# Moved: AI_at_the_Edge__2023___new_release_.pdf (702 pages)
# Moved: data_analysis_and_decision_making_by_Alb.pdf (1090 pages)
# Moved: Computer_Vision__2_.pdf (581 pages)
# Moved: Bishop_Pattern_Recognition_and_Machine_L.pdf (758 pages)
# Moved: 2_Aur_lien_G_ron_Hands_On_Machine_Learni.pdf (510 pages)
# Moved: ChatGPT_for_Beginners.pdf (506 pages)
# Moved: C__Starting.pdf (793 pages)
# Moved: AI__Machine_Learning_and_Deep_Learning.pdf (540 pages)
# Moved: Beginning_C___Game_Programming.pdf (648 pages)
# Moved: Data_Mining_Concepts_And_Techniques_3rd_.pdf (560 pages)
# Moved: Computer_Vision___A_Modern_Approach___D_.pdf (793 pages)
# Moved: Classical_Recursion_Theory.pdf (944 pages)
# Moved: Addison_Wesley___SQL_Server_2005.pdf (737 pages)
# Moved: C___Cookbook.pdf (1469 pages)
# Moved: Clean_Code_Principles_And_Patterns.pdf (588 pages)
# Moved: Distributed_Machine_Learning_with_PySpar_1.pdf (855 pages)
# Moved: Albert_Sweigart_Automate_the_Boring_Stuf.pdf (643 pages)
# Moved: AlgoDailyBookCoreEssentials.pdf (737 pages)
# Moved: Apress_Pro_ASP_NET_MVC.pdf (753 pages)
# Moved: Distributed_Systems.pdf (685 pages)
# Moved: Dive_into_Deep_Learning.pdf (987 pages)
# Moved: Deep_Learning_for_Medical_Image_Analysis.pdf (544 pages)
# Moved: Deep_Learning_Ian_Goodfellow.pdf (800 pages)
# Moved: d2l_en.pdf (982 pages)
# Moved: Essentials_of_Python_for_Artificial_Inte.pdf (524 pages)
# Moved: Fluent_React.pdf (620 pages)
# Moved: d2l_en_mxnet.pdf (1108 pages)
# Moved: Cloud_Native_Software_Security_Handbook.pdf (532 pages)
# Moved: Algorithmic_Thinking.pdf (622 pages)
# Moved: Data_Structures___Algorithms_in_Go.pdf (666 pages)
# Moved: Beginning_Regular_Expressions.pdf (771 pages)
# Moved: Essential_Guide_to_Python_for_all_levels.pdf (510 pages)
# Moved: Hacks__Leaks__and_Revelations.pdf (514 pages)
# Moved: Algorithms_and_Data_Structures_with_Pyth.pdf (534 pages)
# Moved: Deep_Learning_with_PyTorch.pdf (522 pages)
# Moved: Football_Analytics_with_Python___R.pdf (501 pages)
# Moved: codeprogrammer_Scientific_Python_Lecture.pdf (1049 pages)
# Moved: HCIP_Cloud_Computing_V5_0_Lab_Guide.pdf (627 pages)
# Moved: Beginning_with_Web3.pdf (516 pages)
# Moved: Hadoop_The_Definitive_Guide_4_edition_a_.pdf (756 pages)
# Moved: Foundations_of_Data_Science_with_Python.pdf (503 pages)
# Moved: Deep_Learning__2024_.pdf (589 pages)
# Moved: Handbook_of_Computability_Theory__2000_.pdf (735 pages)
# Moved: dm__2_.pdf (700 pages)
# Moved: Handbook_of_Computer_Programming_with_Py.pdf (631 pages)
# Moved: Handbook_of_Data_Structures_and_Applicat.pdf (1321 pages)
# Moved: HCIP_Cloud_Computing_V5_0_Training_Mater.pdf (897 pages)
# Moved: Bishop___Pattern_Recognition_And_Machine.pdf (758 pages)
# Moved: book821f0.pdf (513 pages)
# Moved: Deep_Learning__2_.pdf (656 pages)
# Moved: HCIP_Cloud_Service_Solutions_Architect_V_1.pdf (604 pages)
# Moved: Image_Processing__Analysis__and_Machine_.pdf (930 pages)
# Moved: Douglas_C__Montgomery___Applied_Statisti.pdf (836 pages)
# Moved: Introduction_to_linear_regression_analys.pdf (679 pages)
# Moved: Excel_2016_Formulas_and_Functions.pdf (605 pages)
# Moved: Deep_Reinforcement_Learning_with_Python_.pdf (650 pages)
# Moved: Fourth_International_Conference_on_Image.pdf (741 pages)
# Moved: Handbook_of_Research_on_Emerging_Trends_.pdf (705 pages)
# Moved: Book__Discrete_Mathematics_and_Its_Appli.pdf (1118 pages)
# Moved: Go_Programming___From_Beginner_to_Profes.pdf (680 pages)
# Moved: Building_Data_Science_Applications_with_.pdf (534 pages)
# Moved: Expert_C__.pdf (668 pages)
# Moved: Grokking_Algorithms_In_Python.pdf (532 pages)
# Moved: Effective_Machine_Learning_Teams.pdf (688 pages)
# Moved: Hands_On_Application_Development_with_Py.pdf (652 pages)
# Moved: Introduction_to_Programming_in_Python.pdf (794 pages)
# Moved: Java_Coding_Problems.pdf (1157 pages)
# Moved: Expert_Data_Modeling_with_Power_BI.pdf (854 pages)
# Moved: Deep_Learning_for_Computer_Vision.pdf (563 pages)
# Moved: Head_First_SQL___PDFDrive__.pdf (586 pages)
# Moved: delegateVsEvent.pdf (1974 pages)
# Moved: Java_Coding_Problems__2_.pdf (648 pages)
# Moved: Fundamentals_of_Data_Engineering_docutr_.pdf (544 pages)
# Moved: Intermediate_C_Programming__2024_.pdf (1079 pages)
# Moved: Elements_of_Programming_Interviews_in_Ja.pdf (535 pages)
# Moved: Exploring_JavaScript__2024_.pdf (1163 pages)
# Moved: Introduction_to_Scientific_Computing_and.pdf (563 pages)
# Moved: Laravel.pdf (747 pages)
# Moved: Head_First_Statistics.pdf (717 pages)
# Moved: Java_Cookbook___Problems_and_Solutions_f.pdf (793 pages)
# Moved: Hands_on_Machine_Learning.pdf (510 pages)
# Moved: Introduction_to_Time_Series_Analysis_and.pdf (671 pages)
# Moved: Building_Java_Programs__A_Back_to_Basics.pdf (1177 pages)
# Moved: Java_Persistence_with_NoSQL.pdf (737 pages)
# Moved: Interpretable_Machine_Learning_with_Pyth.pdf (607 pages)
# Moved: IntroductiontoLinearRegressionAnalysisby.pdf (872 pages)
# Moved: Hand_on_ML.pdf (564 pages)
# Moved: Learning_Vue__2023_.pdf (507 pages)
# Moved: Head_First_Statistics_pdf___PDFDrive__.pdf (717 pages)
# Moved: FastAPI_Cookbook.pdf (523 pages)
# Moved: Enhancing_IoT_Security.pdf (862 pages)
# Moved: Larry_Wasserman_ALL_OF_Statistics.pdf (538 pages)
# Moved: HCIA_Big_Data_V3_0_Training_Material.pdf (595 pages)
# Moved: M2_Machine_Learning_By_Ethem_Alpaydin.pdf (579 pages)
# Moved: HTML_and_CSS_Design_and_Build_Websites_J.pdf (514 pages)
# Moved: Job_Ready_Python__2024_.pdf (889 pages)
# Moved: HCIA_Cloud_Service_V3_0_Training_Materia.pdf (514 pages)
# Moved: ISLP_website.pdf (613 pages)
# Moved: Introduction_duction_to_Python_String_Ma.pdf (880 pages)
# Moved: ISLP_website__1_.pdf (613 pages)
# Moved: Human_in_the_Loop_Machine_Learning.pdf (607 pages)
# Moved: HCIA_Storage_V4_5_Training_Material.pdf (621 pages)
# Moved: Learn_C_Programming.pdf (742 pages)
# Moved: ISLRv2_corrected_June_2023.pdf (615 pages)
# Moved: Mastering_Deep_Learning__2023_.pdf (594 pages)
# Moved: Discovery_Science__2023_.pdf (725 pages)
# Moved: Financial_Data_Engineering.pdf (711 pages)
# Moved: ISLRv2_website.pdf (612 pages)
# Moved: Hyperautomation_with_Generative_AI__2023.pdf (812 pages)
# Moved: Machine_Learning_in_Python_for_everyone.pdf (520 pages)
# Moved: Machine_Learning_in_the_AWS_Cloud__2020_.pdf (530 pages)
# Moved: Mastering_Django__Core.pdf (672 pages)
# Moved: M3_Machine_Learning.pdf (1098 pages)
# Moved: Jason_Brownlee__Better_deep_learning___P.pdf (575 pages)
# Moved: Financial_Modeling_Using_Excel_and_VBA.pdf (670 pages)
# Moved: Hypermodern_Python_Tooling.pdf (501 pages)
# Moved: Learning_Digital_Identity.pdf (659 pages)
# Moved: Operating_System_Book.pdf (820 pages)
# Moved: KM204_Course_Guide.pdf (622 pages)
# Moved: Mastering_Flask_Web_and_API_Development.pdf (520 pages)
# Moved: Mastering_HTML_and_CSS_for_Modern_Develo.pdf (629 pages)
# Moved: Machine_Learning_Made_Simple__2023_.pdf (809 pages)
# Moved: Introduction_to_Algorithms__fourth_editi.pdf (1677 pages)
# Moved: Machine_and_Deep_Learning_Using_MATLAB.pdf (590 pages)
# Moved: Mastering_Python__2_.pdf (680 pages)
# Moved: Natural_Language_Processing_with_Python.pdf (505 pages)
# Moved: Microservices_with_Spring_Boot_3_and_Spr.pdf (707 pages)
# Moved: Learn_Java_with_Projects.pdf (602 pages)
# Moved: Learning_GitHub_Actions.pdf (560 pages)
# Moved: Introduction_to_Ansible_Network_Automati.pdf (940 pages)
# Moved: Mastering_Julia.pdf (530 pages)
# Moved: PLC_for_Beginners.pdf (621 pages)
# Moved: Oracle_Linux_Cookbook.pdf (567 pages)
# Moved: Mastering_QuickBooks_2024.pdf (652 pages)
# Moved: Machine_Learning_Theory_and_Applications.pdf (510 pages)
# Moved: Mastering_LLM_Applications_with_LangChai.pdf (526 pages)
# Moved: Practical_SQL.pdf (611 pages)
# Moved: o_Hands_On_Machine_Learning_with_Scikit_.pdf (564 pages)
# Moved: Microsoft_Sql_Server_2005_Reporting_Serv.pdf (566 pages)
# Moved: PostgreSQL_15_Cookbook.pdf (566 pages)
# Moved: Learn_PostgreSQL.pdf (962 pages)
# Moved: Learning_Kali_Linux.pdf (747 pages)
# Moved: Introduction_to_Computer_Programming_wit.pdf (501 pages)
# Moved: Practical_Statistics_for_Data_Scientists.pdf (562 pages)
# Moved: Machine_Learning__2_.pdf (741 pages)
# Moved: NET_MAUI_in_Action.pdf (690 pages)
# Moved: MICROSOFT_SQL_SERVER_A_BEGINNER_S_GUID.pdf (745 pages)
# Moved: Introduction_to_Environmental_Data_Scien.pdf (649 pages)
# Moved: Machine_Learning_and_Big_Data_Analytics.pdf (552 pages)
# Moved: o_Steven_Bird__Ewan_Klein__Edward_Loper_.pdf (504 pages)
# Moved: Mining_of_massive_datasets_v3.pdf (603 pages)
# Moved: LINQ_PRO.pdf (841 pages)
# Moved: Mathematical_Methods_using_Python.pdf (505 pages)
# Moved: MIT_deeplearning.pdf (798 pages)
# Moved: Machine_Learning_by_Tutorials_v2_4_0_055.pdf (586 pages)
# Moved: Machine_Learning_by_Tutorials_v2_4_0_1.pdf (586 pages)
# Moved: Mathematics_and_Computer_Science__2023_.pdf (557 pages)
# Moved: Mastering_MySQL_Administration.pdf (750 pages)
# Moved: Principles_of_Computer_Science.pdf (759 pages)
# Moved: Principles_of_Data_Mining__2024_.pdf (569 pages)
# Moved: Programming_Languages.pdf (574 pages)
# Moved: Making_Embedded_Systems__2024_.pdf (634 pages)
# Moved: Modern_C.pdf (553 pages)
# Moved: Linux_Kernel_Programming.pdf (1175 pages)
# Moved: Processing__2024_.pdf (738 pages)
# Moved: Many_Sorted_Algebras_for_Deep_Learning_a.pdf (816 pages)
# Moved: numerical_analysis_9th.pdf (895 pages)
# Moved: Numerical_Methods_in_Physics_with_Python.pdf (705 pages)
# Moved: Programming_Machine_Learning__2024_.pdf (589 pages)
# Moved: Math_for_Programmers___3D_graphics__mach.pdf (657 pages)
# Moved: Machine_Learning_for_Decision_Makers.pdf (764 pages)
# Moved: Modern_Data_Engineering_with_Apache_Spar.pdf (592 pages)
# Moved: Professional_ADO_NET_2_0__Programming_wi.pdf (644 pages)
# Moved: Machine_Learning_for_Decision_Makers__2_.pdf (676 pages)
# Moved: Modern_X86_Assembly_Language_Programming.pdf (688 pages)
# Moved: Mastering_Python_Algorithms__2024_.pdf (527 pages)
# Moved: PHP_and_Algorithmic_Thinking_for_the_Com.pdf (1356 pages)
# Moved: Object_Oriented_Analysis_and_Design_for_.pdf (727 pages)
# Moved: Learning_Python_5th_Edition.pdf (1594 pages)
# Moved: OpenCV_Computer_Vision_Projects_with_Pyt.pdf (558 pages)
# Moved: Reinforcement_Learning___An_Introduction.pdf (548 pages)
# Moved: Python_Machine_Learning__2_.pdf (731 pages)
# Moved: Professional_C__.pdf (1970 pages)
# Moved: luciano_ramalho_fluent_python_clear_conc.pdf (1011 pages)
# Moved: Statistics_for_Business_and_Economics.pdf (1117 pages)
# Moved: progit.pdf (501 pages)
# Moved: Python_Machine_Learning__4_.pdf (564 pages)
# Moved: Responsive_Web_Development.pdf (512 pages)
# Moved: Richard_J__Larsen__Morris_L__Marx___An_I.pdf (768 pages)
# Moved: Programming__Principles_and_Practice_Usi.pdf (2035 pages)
# Moved: Python_Crashkurs__2024_.pdf (1441 pages)
# Moved: MCTS_Self_Paced_Training_Kit__Exam_70_43.pdf (990 pages)
# Moved: Tensorflow_Machine_Learning__2020_.pdf (517 pages)
# Moved: Text_Mining_with_Python.pdf (505 pages)
# Moved: Statistics_with_Julia.pdf (531 pages)
# Moved: Pro_Angular_16.pdf (847 pages)
# Moved: ROS05665.pdf (546 pages)
# Moved: The_Apache_Ignite_Book.pdf (588 pages)
# Moved: MicroPython_for_the_Internet_of_Things.pdf (578 pages)
# Moved: solidbook.pdf (715 pages)
# Moved: Programming_for_Problem_Solving_with_C.pdf (636 pages)
# Moved: Streaming_Databases.pdf (544 pages)
# Moved: Practical_Java_Programming_with_ChatGPT_.pdf (501 pages)
# Moved: Python__.pdf (727 pages)
# Moved: Practical_Julia__datascienceM.pdf (747 pages)
# Moved: Python_Data_Analytics___Third_Edition.pdf (950 pages)
# Moved: Python_Data_Science_Handbook_Essential_T.pdf (548 pages)
# Moved: Pro_ASP_NET_Core_MVC_2___Adam_Freeman__A.pdf (1024 pages)
# Moved: The_Art_of_Randomness.pdf (871 pages)
# Moved: Time_Series_Analysis__Forecasting_and_Co.pdf (709 pages)
# Moved: Time_series_analysis___PDFDrive__.pdf (619 pages)
# Moved: Python___Deeper_Insights_into_Machine_Le.pdf (901 pages)
# Moved: Python_GUI_with_PyQt.pdf (591 pages)
# Moved: Sams_Teach_Yourself_Python_in_24_Hours__.pdf (787 pages)
# Moved: Practical_Machine_Learning_with_Spark.pdf (554 pages)
# Moved: Python_Programming_for_Students.pdf (534 pages)
# Moved: ScientificPythonLectures_simple.pdf (690 pages)
# Moved: SQL___Course_notes.pdf (1288 pages)
# Moved: Starting_Out_with_C___from_Control_Struc.pdf (1397 pages)
# Moved: Starting_Out_with_Python.pdf (886 pages)
# Moved: Synthetic_Data_and_Generative_AI.pdf (613 pages)
# Moved: The_Pythonic_Way.pdf (512 pages)
# Moved: Python_Internals_for_Developers__2022_.pdf (1108 pages)
# Moved: Tarek_A_Atwan_Time_Series_Analysis_with_.pdf (630 pages)
# Moved: Python_Programming_Using_Problem_Solving.pdf (646 pages)
# Moved: Practical_Natural_Language_Processing.pdf (742 pages)
# Moved: Starting_Out_With_Python__2022_.pdf (917 pages)
# Moved: Scientific_Computing_with_Python.pdf (1809 pages)
# Moved: pythondatasciencehandbook.pdf (548 pages)
# Moved: Python_in_Excel__2024_.pdf (607 pages)
# Moved: The_Rules_of_Programming.pdf (566 pages)
# Moved: TensorFlow_Developer_Certificate_Guide__.pdf (658 pages)
# Moved: Python_Essentials_1.pdf (602 pages)
# Moved: the_Daily_Dose_of_Data_Science_archive.pdf (531 pages)
# Moved: Pythonic_AI__2023_.pdf (590 pages)
# Moved: Rapid_GUI_Programming_with_Python.pdf (643 pages)
# Moved: scikit_learn_user_guide.pdf (2170 pages)
# Moved: Ultimate_Pandas_for_Data_Manipulation_an.pdf (695 pages)
# Moved: The_Deep_Learning_Architect_s_Handbook__.pdf (565 pages)
# Moved: The_Docker_Workshop.pdf (1961 pages)
# Moved: The_R_Book.pdf (883 pages)
# Moved: Tutorials_on_Machine_learning___Deep_Lea.pdf (578 pages)
# Moved: ULTIMATE_Python_Guide__2024_.pdf (715 pages)
# Moved: دليل المالك.pdf (627 pages)
# Moved: Python_for_AI.pdf (763 pages)
# Moved: The_GAN_Book.pdf (652 pages)
# Moved: Scripting.pdf (691 pages)
# Moved: Python_for_Chemists.pdf (559 pages)
# Moved: Wiley_Machine_Learning_Theory.pdf (510 pages)
# Moved: PythonNotesForProfessionals.pdf (816 pages)
# Moved: React_18_Design_Patterns_and_Best_Practi.pdf (717 pages)
# Moved: رياض الصالحين من كلام سيد المرسلين (يحي بن شرف النووي أبو زكريا) (z-lib.org).pdf (679 pages)
# Moved: The_Julia_Language.pdf (1985 pages)
# Moved: React_18_for_Beginners.pdf (524 pages)
# Moved: Y__Daniel_Liang___Intro_to_Java_Programm.pdf (1345 pages)
# Moved: UnderstandingDeepLearning_07_02_24_C.pdf (541 pages)
# Moved: The_Ultimate_Docker_Container_Book.pdf (626 pages)
# Moved: React_and_React_Native.pdf (596 pages)
# Moved: Python_for_DevOps.pdf (725 pages)
# Moved: Understanding_Deep_Learning.pdf (541 pages)
# Moved: الآلات_الكهربائية_والكهروميكانيكا_.pdf (553 pages)
# Moved: T_SQL.pdf (794 pages)
# Moved: Understanding_Deep_Learning__2024_.pdf (541 pages)
# Moved: Python_3.pdf (1039 pages)
# Moved: Ultimate_ChatGPT_Handbook_for_Enterprise.pdf (736 pages)
# Moved: Using_Stable_Diffusion_with_Python.pdf (502 pages)
# Moved: Ultimate_Java_for_Data_Analytics_and_ML.pdf (767 pages)
# Moved: Python_and_Tkinter_Programming.pdf (684 pages)
# Moved: Vue_js_for_Jobseekers.pdf (625 pages)
# Moved: Ultimate_Machine_Learning_Job_Interview_.pdf (510 pages)
# Moved: Python_Apps_on_Visual_Studio_Code.pdf (572 pages)
# Moved: Ultimate_Machine_Learning_with_ML_NET.pdf (603 pages)
# Moved: Python_Based_Data_Structures_and_Algorit.pdf (1003 pages)
# Moved: Web_Data_Mining.pdf (543 pages)
