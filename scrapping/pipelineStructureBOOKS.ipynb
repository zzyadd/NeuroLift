# %%
import os
import time
import requests
import urllib3
import re
import hashlib
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from concurrent.futures import ThreadPoolExecutor

# Disable SSL warnings
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# Constants
BASE_DIR = r"N:\CS\rohana DS\linksTEXT\tryagain"
FOLDERS = range(1, 17)  # From 7 to 16
MAX_THREADS = 5  # Number of concurrent threads
DELAY = 6  # Delay between requests to avoid being blocked

def is_valid_url(url):
    return True

def read_file(file_path):
    """Reads the content of a file if it exists, otherwise returns None."""
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read().strip()
    print(f"Warning: {file_path} not found.")
    return None

def extract_links_from_page(url, selector):
    """Extracts href links from a webpage based on the given selector."""
    try:
        print(f"Processing: {url}")
        time.sleep(DELAY)  # Delay to avoid request throttling
        response = requests.get(url, verify=False, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        target_element = soup.select_one(selector)
        if not target_element:
            print(f"No matching element found for selector '{selector}' in {url}")
            return []

        links = [urljoin(url, a['href']) for a in target_element.find_all('a', href=True)]
        print(f"Found {len(links)} links in {url}")
        return links
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return []

def extract_text_from_page(url, selector, text_output_dir):
    """Extracts text content from a webpage and saves it as a file."""
    try:
        print(f"Fetching text from: {url}")
        time.sleep(DELAY - 1)  # Delay for politeness
        response = requests.get(url, verify=False, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        target_element = soup.select_one(selector)
        if not target_element:
            print(f"No matching text found for selector '{selector}' in {url}")
            return
        
        text_content = target_element.get_text(strip=True)
        filename = os.path.join(text_output_dir, f"{hashlib.md5(url.encode()).hexdigest()}.txt")
        
        with open(filename, "w", encoding="utf-8") as text_file:
            text_file.write(text_content)
        
        print(f"Saved text from {url} to {filename}")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")

def process_folder(folder_num):
    """Processes each folder, extracts links, and scrapes text."""
    folder_path = os.path.join(BASE_DIR, f"{folder_num}")
    
    # Define file paths
    structured_books_file = os.path.join(folder_path, f"{folder_num}_structured_books.txt")
    summary_structure_file = os.path.join(folder_path, f"{folder_num}_summary_structure.txt")
    books_summary_file = os.path.join(folder_path, f"{folder_num}_BooksSummry.txt")
    body_text_file = os.path.join(folder_path, f"{folder_num}_body_text.txt")
    text_output_dir = os.path.join(folder_path, "ExtractedTexts")

    # Ensure output directory exists
    os.makedirs(text_output_dir, exist_ok=True)

    # Read base links
    base_links = read_file(structured_books_file)
    if not base_links:
        return
    base_links = base_links.splitlines()

    # Read selectors
    summary_selector = read_file(summary_structure_file)
    body_selector = read_file(body_text_file)
    if not summary_selector or not body_selector:
        return

    valid_links = [link for link in base_links if is_valid_url(link)]
    if not valid_links:
        print(f"No valid links found in {structured_books_file}")
        return

    # Extracting all links
    extracted_links = []
    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        results = executor.map(lambda url: extract_links_from_page(url, summary_selector), valid_links)
        for result in results:
            extracted_links.extend(result)

    # Save extracted links
    with open(books_summary_file, "w", encoding="utf-8") as file:
        file.write("\n".join(extracted_links))
    print(f"Extracted {len(extracted_links)} links and saved to {books_summary_file}")

    # Extract text from extracted links
    with ThreadPoolExecutor(max_workers=MAX_THREADS) as executor:
        executor.map(lambda url: extract_text_from_page(url, body_selector, text_output_dir), extracted_links)

    print(f"Completed processing for folder #{folder_num}")

def main():
    for folder_num in FOLDERS:
        process_folder(folder_num)

    print("Pipeline execution completed.")

if __name__ == "__main__":
    main()
# Out:
# Warning: N:\CS\rohana DS\linksTEXT\tryagain\1\1_structured_books.txt not found.
# Warning: N:\CS\rohana DS\linksTEXT\tryagain\2\2_structured_books.txt not found.
# Warning: N:\CS\rohana DS\linksTEXT\tryagain\3\3_structured_books.txt not found.
# Processing: https://nustat.github.io/intro-stat-ds/
# Found 249 links in https://nustat.github.io/intro-stat-ds/
# Extracted 249 links and saved to N:\CS\rohana DS\linksTEXT\tryagain\4\4_BooksSummry.txt
# Fetching text from: https://nustat.github.io/intro-stat-ds/index.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/index.html#introduction-for-students
# Fetching text from: https://nustat.github.io/intro-stat-ds/index.html#what-you-will-learn-from-this-book
# Fetching text from: https://nustat.github.io/intro-stat-ds/index.html#datascience-pipeline
# Fetching text from: https://nustat.github.io/intro-stat-ds/index.html#reproducible-research
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/index.html#reproducible-research
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/index.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#r-rstudio
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/index.html#introduction-for-students
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#using-rstudio-cloud
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/index.html#datascience-pipeline
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#installing-r-and-rstudio-on-your-personal-computer
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/index.html#what-you-will-learn-from-this-book
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#using-r-via-rstudio
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#r-rstudio
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#code
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#creating-your-first-r-markdown-document
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#using-rstudio-cloud
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#programming-concepts
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#using-r-via-rstudio
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#errors-warnings-and-messages
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#installing-r-and-rstudio-on-your-personal-computer
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#tips-on-learning-to-code
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#creating-your-first-r-markdown-document
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#packages
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#programming-concepts
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-installation
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#code
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-loading
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#errors-warnings-and-messages
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-use
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#tips-on-learning-to-code
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#nycflights13
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#packages
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#nycflights13-package
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-installation
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#flights-data-frame
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-loading
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#exploredataframes
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#package-use
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#help-files
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#nycflights13
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#gs-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#flights-data-frame
# Fetching text from: https://nustat.github.io/intro-stat-ds/1-getting-started.html#additional-resources
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#exploredataframes
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#nycflights13-package
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#pkgs-2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#help-files
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#grammarofgraphics
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#gs-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#components-of-the-grammar
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#gapminder
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#pkgs-2
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#other-components
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#grammarofgraphics
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#ggplot2-package
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#components-of-the-grammar
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#FiveNG
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/1-getting-started.html#additional-resources
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#scatterplots
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#gapminder
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#geompoint
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#ggplot2-package
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#overplotting
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#other-components
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#FiveNG
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#linegraphs
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#scatterplots
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#geomline
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#geompoint
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#overplotting
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#histograms
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#geomhistogram
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#linegraphs
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#adjustbins
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#geomline
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary-2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#histograms
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#facets
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#boxplots
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#geomhistogram
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#geomboxplot
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#adjustbins
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary-3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary-2
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#geombar
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#facets
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#barplots-via-geom_bar-or-geom_col
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#boxplots
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#must-avoid-pie-charts
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#geomboxplot
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#two-categ-barplot
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary-3
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary-4
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#geombar
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#data-vis-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#barplots-via-geom_bar-or-geom_col
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#summary-table
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#two-categ-barplot
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#argument-specification
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary-4
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#additional-resources-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#must-avoid-pie-charts
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#whats-to-come-3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#summary-table
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#additional-resources-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#pkgs-3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#argument-specification
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#piping
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#whats-to-come-3
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#filter
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#summarize
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#data-vis-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#groupby
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#pkgs-3
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#grouping-by-more-than-one-variable
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#piping
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#mutate
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#filter
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#arrange
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#summarize
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#joins
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#groupby
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#matching-key-variable-names
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#grouping-by-more-than-one-variable
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#diff-key
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#mutate
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#multiple-key-variables
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#arrange
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#normal-forms
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#joins
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#other-verbs
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#matching-key-variable-names
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#select
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#diff-key
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#rename
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#normal-forms
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#top_n-values-of-a-variable
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#multiple-key-variables
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#wrangling-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#select
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#summary-table-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#other-verbs
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#additional-resources-2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#rename
# Fetching text from: https://nustat.github.io/intro-stat-ds/3-wrangling.html#whats-to-come
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#top_n-values-of-a-variable
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#wrangling-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#pkgs-4
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#additional-resources-2
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#csv
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#summary-table-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#using-the-console
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/3-wrangling.html#whats-to-come
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#using-rstudios-interface
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#tidy-data-ex
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#pkgs-4
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#definition-of-tidy-data
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#csv
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#converting-to-tidy-data
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#using-rstudios-interface
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#nycflights13-package-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#using-the-console
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#case-study-tidy
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#definition-of-tidy-data
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#tidy-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#tidy-data-ex
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#tidyverse-package
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#converting-to-tidy-data
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#additional-resources-3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#nycflights13-package-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/4-tidy.html#whats-to-come-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#case-study-tidy
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#tidyverse-package
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#pkgs-5
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#tidy-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#additional-resources-3
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model1EDA
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/4-tidy.html#whats-to-come-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model1table
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model1points
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model1
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#pkgs-5
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model2EDA
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model1EDA
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model2table
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model1points
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#model2points
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model1table
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#related-topics
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model2EDA
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#correlationcoefficient
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model2
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#correlation-is-not-causation
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#related-topics
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#leastsquares
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model2points
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#basic-reg-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#correlationcoefficient
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#additional-resources-basic-regression
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#model2table
# Fetching text from: https://nustat.github.io/intro-stat-ds/5-regression.html#whats-to-come-2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#correlation-is-not-causation
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#leastsquares
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#pkgs-6.
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#additional-resources-basic-regression
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3EDA
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#basic-reg-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3table
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/5-regression.html#whats-to-come-2
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3points
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#pkgs-6.
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4EDA
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3table
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4interactiontable
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3EDA
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4table
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model3points
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4points
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#related-topics-1
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4interactiontable
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model-selection
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4EDA
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#correlationcoefficient2
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4table
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#simpsonsparadox
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model4points
# Fetching text from: https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#multi-reg-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#related-topics-1
# Fetching text from: https://nustat.github.io/intro-stat-ds/2-viz.html#whats-to-come-3
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#model-selection
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#simpsonsparadox
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#pkgs-7
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#correlationcoefficient2
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#causal-questions
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/6-multiple-regression.html#multi-reg-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#randomized-experiments
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/2-viz.html#whats-to-come-3
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#random-processes-in-r
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#omitted-variables
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#pkgs-7
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#the-magic-of-randomization
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#causal-questions
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#ed-data
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#randomized-experiments
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#estimating-the-treatment-effect
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#omitted-variables
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#if-you-know-z-what-about-multiple-regression
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#random-processes-in-r
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#what-if-you-dont-know-z
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#the-magic-of-randomization
# Fetching text from: https://nustat.github.io/intro-stat-ds/7-causality.html#causality-conclusion
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#ed-data
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#estimating-the-treatment-effect
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#pkgs-8
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#what-if-you-dont-know-z
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#terminology
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#if-you-know-z-what-about-multiple-regression
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#sample-selection
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#movie-example
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/7-causality.html#causality-conclusion
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#research-question
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#pkgs-8
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#population-of-interest
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#terminology
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#development-of-population-frame
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#sample-selection
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#sampling-plan
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#research-question
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#samples
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#movie-example
# Fetching text from: https://nustat.github.io/intro-stat-ds/8-populations.html#causality-vs.-generalizability
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#population-of-interest
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#development-of-population-frame
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#pkgs-9
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#samples
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#parametric
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#causality-vs.-generalizability
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#normal-distribution
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/8-populations.html#sampling-plan
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#empirical-rule
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/9-sampling.html
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#standardization
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/9-sampling.html#pkgs-9
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#t-distribution
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/9-sampling.html#parametric
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#normal-vs-t
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/9-sampling.html#empirical-rule
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#chi-squared-distribution
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed' in https://nustat.github.io/intro-stat-ds/9-sampling.html#normal-distribution
# Fetching text from: https://nustat.github.io/intro-stat-ds/9-sampling.html#repeated-sampling
# ...
# Fetching text from: https://smltar.com/dldnn#in-this-chapter-you-learned-7
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dldnn#dnncross
# Fetching text from: https://smltar.com/dllstm
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dldnn#compare-and-evaluate-dnn-models
# Fetching text from: https://smltar.com/dllstm#firstlstm
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dldnn#dllimitations
# Fetching text from: https://smltar.com/dllstm#building-an-lstm
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dldnn#dldnnsummary
# Fetching text from: https://smltar.com/dllstm#lstmevaluation
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dldnn#in-this-chapter-you-learned-7
# Fetching text from: https://smltar.com/dllstm#compare-to-a-recurrent-neural-network
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm
# Fetching text from: https://smltar.com/dllstm#bilstm
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#firstlstm
# Fetching text from: https://smltar.com/dllstm#case-study-stacking-lstm-layers
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#building-an-lstm
# Fetching text from: https://smltar.com/dllstm#lstmpadding
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#lstmevaluation
# Fetching text from: https://smltar.com/dllstm#case-study-training-a-regression-model
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#compare-to-a-recurrent-neural-network
# Fetching text from: https://smltar.com/dllstm#case-study-vocabulary-size
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#bilstm
# Fetching text from: https://smltar.com/dllstm#lstmfull
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#case-study-stacking-lstm-layers
# Fetching text from: https://smltar.com/dllstm#lstmfullpreprocess
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#lstmpadding
# Fetching text from: https://smltar.com/dllstm#lstmfullmodel
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#case-study-training-a-regression-model
# Fetching text from: https://smltar.com/dllstm#dllstmsummary
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#case-study-vocabulary-size
# Fetching text from: https://smltar.com/dllstm#in-this-chapter-you-learned-8
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#lstmfull
# Fetching text from: https://smltar.com/dlcnn
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#lstmfullpreprocess
# Fetching text from: https://smltar.com/dlcnn#what-are-cnns
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#lstmfullmodel
# Fetching text from: https://smltar.com/dlcnn#kernel
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#dllstmsummary
# Fetching text from: https://smltar.com/dlcnn#kernel-size
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dllstm#in-this-chapter-you-learned-8
# Fetching text from: https://smltar.com/dlcnn#firstcnn
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn
# Fetching text from: https://smltar.com/dlcnn#case-study-adding-more-layers
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#what-are-cnns
# Fetching text from: https://smltar.com/dlcnn#case-study-byte-pair-encoding
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#kernel
# Fetching text from: https://smltar.com/dlcnn#lime
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#kernel-size
# Fetching text from: https://smltar.com/dlcnn#keras-hyperparameter
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#firstcnn
# Fetching text from: https://smltar.com/dlcnn#cross-validation-for-evaluation
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#case-study-adding-more-layers
# Fetching text from: https://smltar.com/dlcnn#cnnfull
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#case-study-byte-pair-encoding
# Fetching text from: https://smltar.com/dlcnn#cnnfullpreprocess
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#lime
# Fetching text from: https://smltar.com/dlcnn#cnnfullmodel
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#keras-hyperparameter
# Fetching text from: https://smltar.com/dlcnn#dlcnnsummary
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#cross-validation-for-evaluation
# Fetching text from: https://smltar.com/dlcnn#in-this-chapter-you-learned-9
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#cnnfull
# Fetching text from: https://smltar.com/text-models-in-the-real-world
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#cnnfullpreprocess
# Fetching text from: https://smltar.com/regexp
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#cnnfullmodel
# Fetching text from: https://smltar.com/regexp#literal-characters
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#dlcnnsummary
# Fetching text from: https://smltar.com/regexp#meta-characters
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/dlcnn#in-this-chapter-you-learned-9
# Fetching text from: https://smltar.com/regexp#full-stop-the-wildcard
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/text-models-in-the-real-world
# Fetching text from: https://smltar.com/regexp#character-classes
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp
# Fetching text from: https://smltar.com/regexp#shorthand-character-classes
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#literal-characters
# Fetching text from: https://smltar.com/regexp#quantifiers
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#meta-characters
# Fetching text from: https://smltar.com/regexp#anchors
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#full-stop-the-wildcard
# Fetching text from: https://smltar.com/regexp#additional-resources
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#character-classes
# Fetching text from: https://smltar.com/appendixdata
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#shorthand-character-classes
# Fetching text from: https://smltar.com/appendixdata#hcandersen
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#quantifiers
# Fetching text from: https://smltar.com/appendixdata#scotus-opinions
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#anchors
# Fetching text from: https://smltar.com/appendixdata#cfpb-complaints
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/regexp#additional-resources
# Fetching text from: https://smltar.com/appendixdata#kickstarter-blurbs
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixdata
# Fetching text from: https://smltar.com/appendixbaseline
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixdata#hcandersen
# Fetching text from: https://smltar.com/appendixbaseline#read-in-the-data
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixdata#scotus-opinions
# Fetching text from: https://smltar.com/appendixbaseline#split-into-testtrain-and-create-resampling-folds
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixdata#cfpb-complaints
# Fetching text from: https://smltar.com/appendixbaseline#recipe-for-data-preprocessing
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixdata#kickstarter-blurbs
# Fetching text from: https://smltar.com/appendixbaseline#lasso-regularized-classification-model
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline
# Fetching text from: https://smltar.com/appendixbaseline#a-model-workflow
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#read-in-the-data
# Fetching text from: https://smltar.com/appendixbaseline#tune-the-workflow
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#split-into-testtrain-and-create-resampling-folds
# Fetching text from: https://smltar.com/references
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#recipe-for-data-preprocessing
# Fetching text from: https://github.com/rstudio/bookdown
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#lasso-regularized-classification-model
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#a-model-workflow
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/appendixbaseline#tune-the-workflow
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://smltar.com/references
# No matching text found for selector 'body > div.book.without-animation.with-summary.font-size-2.font-family-1 > div.book-body.fixed > div > div.page-wrapper' in https://github.com/rstudio/bookdown
# Completed processing for folder #14
# Warning: N:\CS\rohana DS\linksTEXT\tryagain\15\15_structured_books.txt not found.
# Warning: N:\CS\rohana DS\linksTEXT\tryagain\16\16_structured_books.txt not found.
# Pipeline execution completed.
