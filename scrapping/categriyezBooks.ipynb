# %%
import os
import shutil
import multiprocessing

# Root directory to search in
root_folder = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS"
# Destination folder for SQL-related PDFs
sql_folder = os.path.join(root_folder, "SQL")

# Ensure the destination folder exists
os.makedirs(sql_folder, exist_ok=True)

# Function to process a single PDF file
def process_pdf(file_info):
    file_path, filename = file_info  # Unpack tuple

    # Check if "sql" (case insensitive) is in the filename
    if "nosql" in filename.lower():
        destination_path = os.path.join(sql_folder, filename)
        try:
            shutil.move(file_path, destination_path)
            print(f"Moved: {filename} → {sql_folder}")
        except Exception as e:
            print(f"Error moving {filename}: {e}")

if __name__ == "__main__":
    # Collect all PDF files recursively
    pdf_files = []
    for folder, _, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(".pdf"):  # Ensure it's a PDF
                pdf_files.append((os.path.join(folder, file), file))  # Store (full_path, filename)
    
    # Use multiprocessing to speed up the process
    num_workers = min(multiprocessing.cpu_count(), len(pdf_files))  # Use optimal number of workers
    with multiprocessing.Pool(processes=num_workers) as pool:
        pool.map(process_pdf, pdf_files)
# Out:
# Moved: Java_Persistence_with_NoSQL.pdf → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/SQL
# Moved: NoSQL.pdf → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/SQL
# Moved: NoSQL_and_SQL_Data_Modeling.pdf → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/SQL
# Moved: NoSQL_Databases.pdf → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/SQL
# Moved: SQL_and_NoSQL_Interview_Questions__2023_.pdf → /mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS/SQL

# %%
import os
import shutil
import multiprocessing

# Root directory to search in
root_folder = "/mnt/c/Users/Zy565/Downloads/EXHD/dataNEOUROlift/BOOKS"

# Keywords and destination folders
categories = {
    "Computer_Science": ["computer science", "cs", "algorithms", "data structures"],
    "Java": ["java"],
    "Python": ["python"],
    "C++": ["c++"],
    "Network_Security": ["network", "security", "cybersecurity"],
}

# Ensure all destination folders exist
for folder in categories.keys():
    os.makedirs(os.path.join(root_folder, folder), exist_ok=True)

# Function to process a single PDF file
def process_pdf(file_info):
    file_path, filename = file_info  # Unpack tuple
    lower_filename = filename.lower()  # Convert filename to lowercase for case-insensitive matching

    # Check which category the file belongs to
    for category, keywords in categories.items():
        if any(keyword in lower_filename for keyword in keywords):  # Match any keyword
            destination_path = os.path.join(root_folder, category, filename)
            try:
                shutil.move(file_path, destination_path)
                print(f"Moved: {filename} → {category}/")
            except Exception as e:
                print(f"Error moving {filename}: {e}")
            return  # Stop after first match

if __name__ == "__main__":
    # Collect all PDF files recursively
    pdf_files = []
    for folder, _, files in os.walk(root_folder):
        for file in files:
            if file.lower().endswith(".pdf"):  # Ensure it's a PDF
                pdf_files.append((os.path.join(folder, file), file))  # Store (full_path, filename)
    
    # Use multiprocessing to speed up the process
    num_workers = min(multiprocessing.cpu_count(), len(pdf_files))  # Use optimal number of workers
    with multiprocessing.Pool(processes=num_workers) as pool:
        pool.map(process_pdf, pdf_files)
# Out:
# Moved: 07_Partioning_and_collecting_algorithms.pdf → Computer_Science/
# Moved: 117_Probability_Statistics_Final_Exam_So.pdf → Computer_Science/
# Moved: Cheat_Sheets_for_AI__Neural_Networks__Ma.pdf → Network_Security/
# Moved: 001_Course_notes_inferential_statistics.pdf → Computer_Science/
# Moved: CS3304_9_LanguageSyntax_2.pdf → Computer_Science/
# Moved: intermediate_python_ch1_slides.pdf → Python/
# Moved: A_guide_to_Face_Detection_in_Python___To.pdf → Python/
# Moved: Build_an_Email_Spider_with_Python.pdf → Python/
# Moved: Face_Detection_with_Python.pdf → Python/
# Moved: Learning_Python__From_Zero_to_Hero___fre.pdf → Python/
# Moved: Epic_Python_Coding.pdf → Python/
# Moved: 25_most_popular_Python_scripts_for_netwo.pdf → Python/Moved: 099_Test_statistics_for_one_and_two_tail.pdf → Computer_Science/
#
# Moved: 140_python_exercises.pdf → Python/
# Moved: Comprehensive_Python_Cheatsheet.pdf → Python/
# Moved: 002_Course_notes_inferential_statistics.pdf → Computer_Science/
# Moved: CS3352.pdf → Computer_Science/
# Moved: intermediate_python_ch2_slides.pdf → Python/
# Moved: A_Hybrid_Neural_Network_Architecture_to_.pdf → Network_Security/
# Moved: C++ للمبتدئين.pdf → C++/
# Moved: Getting_Analytics_Right_.pdf → Computer_Science/
# Moved: Learn_Python_with_Examples_2024.pdf → Python/
# Moved: EthicsofAI.pdf → Computer_Science/
# Moved: 4__Python_variables___constant_and_liter.pdf → Python/
# Moved: 100_Essential_Python_Interview_Questions.pdf → Python/
# Moved: Linear_Regression_in_Python___Real_Pytho.pdf → Python/
# Moved: Contemporary_Linguistics_Ch_17.pdf → Computer_Science/
# Moved: 002_Probability_Statistics_formulas.pdf → Computer_Science/
# Moved: CS361_Artificial_Intelligence__SEP__Lect.pdf → Computer_Science/
# Moved: intermediate_python_ch3_slides.pdf → Python/
# Moved: beginners_guide_to_data_science__a_twics.pdf → Computer_Science/
# Moved: Mathemitcs_of_Neural_Networks.pdf → Computer_Science/
# Moved: Grokking_Algorithms_Summary__Herfy_.pdf → Computer_Science/
# Moved: network_analysis_in_R.pdf → Network_Security/
# Moved: Practical_Statistics___Visualization_Wit.pdf → Computer_Science/
# Moved: 5__python_variables__datatypes.pdf → Python/
# Moved: 100_Python_Program_Examples.pdf → Python/
# Moved: Statistics_in_python.pdf → Computer_Science/
# Moved: Copy_of_1__Python.pdf → Python/
# Moved: 003_Course_notes_descriptive_statistics.pdf → Computer_Science/
# Moved: CS361_Artificial_Intelligence__SEP__Lect_1.pdf → Computer_Science/
# Moved: intermediate_python_ch4_slides.pdf → Python/
# Moved: BIG_Data_Analytics.pdf → Computer_Science/
# Moved: migrating_big_data_analytics.pdf → Computer_Science/
# Moved: How_To_Python.pdf → Python/
# Moved: Neutral_Network.pdf → Network_Security/
# Moved: Python_cheatsheet.pdf → Python/
# Moved: 60_Exercices_corrig_s_en_Python_1_.pdf → Python/
# Moved: Think_Python__2023__3rd_Edition__Chapter.pdf → Python/
# Moved: The_5_Feature_Selection_Algorithms_every.pdf → Computer_Science/
# Moved: Course_notes_descriptive_statistics.pdf → Computer_Science/
# Moved: 004_Course_notes_descriptive_statistics.pdf → Computer_Science/
# Moved: intermediate_python_ch5_slides.pdf → Python/
# Moved: CS361_Artificial_Intelligence__SEP__Lect_2.pdf → Computer_Science/
# Moved: big_data_analytics_emerging_architecture.pdf → Computer_Science/
# Moved: How_to_scrape_websites_with_Python_and_B.pdf → Python/
# Moved: حلول اسالة c++.pdf → C++/
# Moved: Adam_Stewart__Python_Programming___Pytho.pdf → Python/
# Moved: Python_Cheatsheet_1630774398.pdf → Python/
# Moved: 80_Python_Interview_Questions.pdf → Python/
# Moved: Time_series_analysis_in_Python.pdf → Python/
# Moved: THE_BEST_Python_LIBRARIES__2024_.pdf → Python/
# Moved: Course_notes_inferential_statistics.pdf → Computer_Science/
# Moved: 011_02_Command_Basics.pdf → Computer_Science/
# Moved: Introdcution_to_Javascript.pdf → Java/
# Moved: CS361_Artificial_Intelligence__SEP__Lect_3.pdf → Computer_Science/
# Moved: Exploring_University_Mathematics_with_Py.pdf → Computer_Science/
# Moved: How_to_Use_Python_lambda_Functions___Rea.pdf → Python/
# Moved: مقدمة في البرمجة بلغة (c++).pdf → C++/
# Moved: Advanced_Image_Processing_with_Python_an.pdf → Python/
# Moved: Python_cheat_sheet.pdf → Python/
# Moved: 8__python_operators.pdf → Python/
# Moved: Time_Series_Forecasting_using_Python.pdf → Python/
# Moved: Mastering_Python.pdf → Python/
# Moved: Course_notes_inferential_statistics__1_.pdf → Computer_Science/
# Moved: MASTERING_PYTHON_FOR_DATA_SCIENCE_WITH_N.pdf → Python/
# Moved: 028_Course_notes_inferential_statistics.pdf → Computer_Science/
# Moved: JavaScript_Built_in_objects.pdf → Java/
# Moved: CSS2c56c.pdf → Computer_Science/
# Moved: Grokking_the_Java_Interview.pdf → Java/
# Moved: Python_Programming_Handbook_For_GUI_Deve.pdf → Python/
# Moved: 100_Page_Python_Intro.pdf → Python/
# Moved: A_Simple_Introduction_to_Python.pdf → Python/
# Moved: Python_Cheat_Sheet_1650363857.pdf → Python/
# Moved: كتاب دليل سريع في لغة الـ c++.pdf → C++/
# Moved: Top_100_Python_questions.pdf → Python/
# Moved: Crowdsourcing_Analytics___Final_Manuscri.pdf → Computer_Science/
# Moved: Mastering_Python_Programming.pdf → Python/
# Moved: 029_Course_notes_inferential_statistics.pdf → Computer_Science/
# Moved: Javascript_Programming__2024_.pdf → Java/
# Moved: Cyber_Security_Interview_Questions.pdf → Network_Security/
# Moved: GUI_Programming_with_Python.pdf → Python/
# Moved: Python_Programming_Handbook_For_IoT_Deve.pdf → Python/
# Moved: 120_Advanced_JavaScript_Interview_Questi.pdf → Java/
# Moved: Basics_of_Image_Processing.pdf → Computer_Science/
# Moved: Python_for_Beginners__2_.pdf → Python/
# Moved: كتاب عن لغة c++.pdf → C++/
# Moved: Top_10_Machine_Learning_Algorithms.pdf → Computer_Science/
# Moved: CS229_Linear_Algebra.pdf → Computer_Science/
# Moved: Neural_Networks_Using_C__Succinctly.pdf → Network_Security/
# Moved: Advanced_Machine_Learning_with_Python.pdf → Python/
# Moved: Java_1.pdf → Java/
# Moved: C_____Python_for_Beginners.pdf → Python/
# Moved: How_to_Lie_with_Statistics.pdf → Computer_Science/
# Moved: Python_Programming_Handbook_For_Robotics.pdf → Computer_Science/
# Moved: 150__JavaScript_Pattern_Programs.pdf → Java/
# Moved: BIG_DATA_HADOOP_AND_JAVA_CODING_MADE_SIM.pdf → Java/
# Moved: 150__Python_Pattern_Programs__2024_.pdf → Python/
# Moved: Python_learning_with_codes_Questions_and.pdf → Python/
# Moved: موسوعة البرمجة بلغة ال C++.pdf → C++/
# Moved: Visualising_Quantum_Mechanics_with_Pytho.pdf → Computer_Science/
# Moved: Bayesian_Analysis_with_Python__2024_.pdf → Python/
# Moved: Nichola_Lacey__Python_by_Example__Learni.pdf → Python/
# Moved: Algorithms_for_Data_Science___PDFDrive__.pdf → Computer_Science/
# Moved: Computer_Vision_with_Python_3_2017.pdf → Python/
# Moved: Data_Lifecycle_and_Analytics.pdf → Computer_Science/
# Moved: How_to_program_in_PYTHON.pdf → Python/
# Moved: Python_programming_workbook_for_blockcha.pdf → Python/
# Moved: byte_of_python.pdf → Python/
# Moved: 190__Python_Interview_Questions_and_Answ.pdf → Python/
# Moved: Python_Notes_Mahmoud_Essam_.pdf → Python/
# Moved: Data_Structures_and_Algorithms_with_Go.pdf → Computer_Science/
# Moved: 100 سؤال حول c++ مع الحلول.pdf → C++/
# Moved: Beginning_ChatGPT_for_Python__2024_.pdf → Python/
# Moved: OPENCV___Python_for_Computer_Vision.pdf → Python/
# Moved: Algorithms_with_JULIA.pdf → Computer_Science/
# Moved: Cryptography_Algorithms.pdf → Computer_Science/
# Moved: Extending_Power_BI_with_Python_and_R.pdf → Python/
# Moved: Java_Cheat_Sheet.pdf → Java/
# Moved: First_Course_in_Algorithms__0AThrough_Pu.pdf → Computer_Science/
# Moved: Python_programming_workbook_for_machine_.pdf → Python/
# Moved: Coding_JavaScript__2024_.pdf → Java/
# Moved: 2014_Book_ThePythonWorkbook.pdf → Python/
# Moved: Python_Pandas_Quick_Refresher.pdf → Python/
# Moved: Data_Structures_and_Algorithms_with_Pyth.pdf → Computer_Science/
# Moved: 12_Twisted_Python_Projects_for_Young_Cod.pdf → Python/
# Moved: Beginning_Programming_with_Python_For_Du.pdf → Python/
# Moved: Portable_Python_Projects__2022_.pdf → Python/
# Moved: Al_Sweigart_The_Big_Book_of_Small_Python.pdf → Python/
# Moved: Cybersecurity_Architect_s_Handbook.pdf → Network_Security/
# Moved: Learning_Advanced_Python_by_Studying_Ope.pdf → Python/
# Moved: Football_Analytics_with_Python_and_R.pdf → Computer_Science/
# Moved: Python_Programming_Workbook_for_Web_Scra.pdf → Python/
# Moved: Coffee_Break_Python.pdf → Python/
# Moved: 50_Python_Concepts_Every_Developer_Shoul.pdf → Python/
# Moved: Python_Print_function.pdf → Python/
# Moved: Data_Structures_in_Java.pdf → Java/
# Moved: 2004_Book_AllOfStatistics.pdf → Computer_Science/
# Moved: Better_Python_Code.pdf → Python/
# Moved: Practical_Python_and_OpenCV.pdf → Python/
# Moved: Applied_Math_for_Security.pdf → Network_Security/
# Moved: CyberSecurity_in_a_DevOps_Environment.pdf → Network_Security/
# Moved: Learn_Python_Fast_Deep_Simple.pdf → Python/
# Moved: Python_Tips_and_Tricks.pdf → Python/
# Moved: Full_Stack_Python_Security.pdf → Python/
# Moved: Complete_Guide_to_Python_Programming.pdf → Python/
# Moved: 50_Python_Concepts_Every_Developer_Shoul_1.pdf → Python/
# Moved: Python___Intro_.pdf → Python/
# Moved: Data_Structure_in_Python.pdf → Python/
# Moved: 2008_Book_IntroductoryStatisticsWithR.pdf → Computer_Science/
# Moved: Beyond_Algorithms__Delivering_AI_for_Bus.pdf → Computer_Science/
# Moved: Python_Advanced_Programming.pdf → Python/
# Moved: Applied_Statistics_with_Python.pdf → Computer_Science/
# Moved: datascienceM_An_Introduction_to_Python_P.pdf → Python/
# Moved: Linear_Regression_With_Python.pdf → Python/
# Moved: Python___Pandas___Beginner_to_Intermedia.pdf → Python/
# Moved: Generative_AI_Foundations_in_Python.pdf → Python/
# Moved: Data_Analytics_for_Discourse_Analysis_wi.pdf → Computer_Science/
# Moved: 80__Python_Coding_Challenges_for_Beginne.pdf → Python/
# Moved: Python___Intro_to_Linear_Regression.pdf → Python/
# Moved: Data_Visualization_with_Python.pdf → Python/
# Moved: 2015__Learning_Java_by_Building_Android_.pdf → Java/
# Moved: Big_Data_Analytics__2024_.pdf → Computer_Science/
# Moved: Python_Cheat_Sheet__2_.pdf → Python/
# Moved: Artificial_Intelligence_for_Robotics.pdf → Computer_Science/
# Moved: datascienceM_Mastering_Python_for_Artifi.pdf → Python/
# Moved: Machine_Learning_Mastery_with_Python.pdf → Python/
# Moved: Recurrent_Neural_Networks__2016_.pdf → Network_Security/
# Moved: Generative_Art_with_JavaScript_and_SVG.pdf → Java/
# Moved: Deep_Learning_Networks.pdf → Network_Security/
# Moved: Abella_Hernando_120_Advanced_Python_Inte.pdf → Python/
# Moved: Hands_On_Web_Scraping_with_Python.pdf → Python/
# Moved: Data_Visualization_with_Python_for_Begin.pdf → Python/
# Moved: 201_Python_Programming_Exercises_For_All.pdf → Python/
# Moved: Biopython.pdf → Python/
# Moved: Python_Exercises_with_Data_Structures_an.pdf → Python/
# Moved: Azure_Security.pdf → Network_Security/
# Moved: datascienceM_Python_Mastery__2023_.pdf → Python/
# Moved: Machine_Learning_Methods_for_Multi_Omics.pdf → Computer_Science/
# Moved: Retail_Analytics__Integrated_Forecasting.pdf → Computer_Science/
# Moved: ggplot2_elegant_graphics_for_data_analys.pdf → Computer_Science/
# Moved: Kirthi_Raman___Mastering_Python_Data_Vis.pdf → Python/
# Moved: Machine_Learning_in_Java.pdf → Java/
# Moved: head_first_python.pdf → Python/
# Moved: Deep_Time_Series_Forecasting_with_Python.pdf → Python/
# Moved: 250__Killer_Python_One_Liners__2024_.pdf → Python/
# Moved: Bio_inspired_Algorithms_in_Machine_Learn.pdf → Computer_Science/
# Moved: Python_for_Beginners.pdf → Python/
# Moved: A_Brief_Introduction_to_neaural_networks.pdf → Network_Security/
# Moved: datascienceM_Python__3_books_in_1.pdf → Python/
# Moved: Machine_Learning_With_Python.pdf → Python/
# Moved: The_1_Page_Python_Book.pdf → Python/
# Moved: Google_Gemini_for_Python.pdf → Python/
# Moved: Large_Scale_Machine_Learning_with_Python.pdf → Python/
# Moved: Machine_Learning_in_Python_for_Dynamic_P.pdf → Python/
# Moved: How_to_Master_Python_in_30_Days.pdf → Python/
# Moved: Descriptive_Analytics.pdf → Computer_Science/
# Moved: 270__Cyber_Security_Interview_Questions_.pdf → Network_Security/
# Moved: Building_AI_Intensive_Python_Application.pdf → Python/
# Moved: Python_for_Data_Analysis.pdf → Python/
# Moved: A_Course_in_Python.pdf → Python/
# Moved: Data_Algorithms_with_Spark__2022_.pdf → Computer_Science/
# Moved: Machine_Learning_with_Python__2024_.pdf → Python/
# Moved: The_Python_Advantage.pdf → Python/
# Moved: Graph_Algorithms_for_Data_Science.pdf → Computer_Science/
# Moved: Learning_Algorithms_George_T_Heineman.pdf → Computer_Science/
# Moved: Mastering_Machine_Learning_with_Python_i.pdf → Python/
# Moved: Information_Security_Handbook.pdf → Network_Security/
# Moved: Discovering_Cybersecurity.pdf → Network_Security/
# Moved: 410__Python_Interview_Questions_and_Answ.pdf → Python/
# Moved: Building_ETL_Pipelines_with_Python__2024.pdf → Python/
# Moved: Python_for_Data_Science__2_.pdf → Python/
# Moved: A_Z_in_Python.pdf → Python/
# Moved: Data_Analytics_and_Adaptive_Learning.pdf → Computer_Science/
# Moved: The_Python_Bible_for_Beginners.pdf → Python/
# Moved: Data_Analytics_and_Machine_Learning.pdf → Computer_Science/
# Moved: Metaheuristic_Algorithms.pdf → Computer_Science/
# Moved: grokking_Algorithms.pdf → Computer_Science/
# Moved: Learning_Professional_Python___Volume_1.pdf → Python/
# Moved: Mastering_Neural_Networks.pdf → Network_Security/
# Moved: Intermediate_Python.pdf → Python/
# Moved: Django_2_2___Python.pdf → Python/
# Moved: 6_Practical_Python_AI_Projects.pdf → Python/
# Moved: Building_Python_Microservices_with_FastA.pdf → Python/
# Moved: Python_for_Information_Professionals__20.pdf → Python/
# Moved: Practical_Guide_to_Python.pdf → Python/
# Moved: The_Python_Bible_for_Beginners__2024_.pdf → Python/
# Moved: Data_Analytics_Book_1638257789.pdf → Computer_Science/
# Moved: MicroPython__2023_.pdf → Python/
# Moved: Grokking_Algorithms__2_.pdf → Computer_Science/
# Moved: Learning_Professional_Python___Volume_2.pdf → Python/
# Moved: Mastering_OpenCV_with_Python.pdf → Python/
# Moved: Internet_of_Things_with_Python___Dynamic.pdf → Python/
# Moved: Django_Python_book__2024_.pdf → Python/
# Moved: 9_Data_Science_Fundamentals_for_Python_a.pdf → Python/
# Moved: Build_a_Backend_REST_API_with_Python___D.pdf → Python/
# Moved: Python_for_OSINT.pdf → Python/
# Moved: Practices_of_the_Python_Pro.pdf → Python/
# Moved: Data_Analytics_Essentials_You_Always_Wan.pdf → Computer_Science/
# Moved: The_Ultimate_Guide_to_PYTHON_CERTIFICATI.pdf → Python/
# Moved: Data_Analytics_Practical_Guide.pdf → Computer_Science/
# Moved: Grokking_Algorithms__Aditya_Y__Bhargava_.pdf → Computer_Science/
# Moved: Mobile_Python_Rapid_Prototyping.pdf → Python/
# Moved: Learn_Advanced_Java_Programming_with_Beg.pdf → Java/
# Moved: Mastering_Python_Design_Patterns__2024_.pdf → Python/
# Moved: Introduction_to_Cybersecurity__2023_.pdf → Network_Security/
# Moved: Mastering_Python_for_Data_Science.pdf → Python/
# Moved: Dynamic_Programming_in_Python.pdf → Python/
# Moved: Absolute_Beginner_s_Guide_to_Python_Prog.pdf → Python/
# Moved: Challenging_Programming_in_Python.pdf → Python/
# Moved: Python_GUI_Automation_for_Beginners.pdf → Python/
# Moved: Prediction_Machines_The_Simple_Economics.pdf → Computer_Science/
# Moved: Tkinter_GUI_Projects_with_Python.pdf → Python/
# Moved: Data_Analytics_with_SAS.pdf → Computer_Science/
# Moved: Guida_pratica_a_Python.pdf → Python/
# Moved: Modern_Graph_Theory_Algorithms_with_Pyth.pdf → Computer_Science/
# Moved: Learn_Autonomous_Programming_with_Python.pdf → Python/
# Moved: Introduction_to_Genetic_Algorithms.pdf → Computer_Science/
# Moved: Mastering_Python_for_Web.pdf → Python/
# Moved: Essential_Statistics_for_Non_STEM_Data_A.pdf → Computer_Science/
# Moved: Academy_of_Python.pdf → Python/
# Moved: codeprogrammer_CS229_Lectures_Notes__202.pdf → Computer_Science/
# Moved: Python_Handwritten_Notes__2023_.pdf → Python/
# Moved: Programming_Algorithms.pdf → Computer_Science/
# Moved: Twisted_Python_Projects.pdf → Python/
# Moved: Data_Mining_with_Python.pdf → Python/
# Moved: Hacking_Secret_Ciphers_with_Python.pdf → Python/
# Moved: Molecular_Networking.pdf → Network_Security/
# Moved: Python_for_Machine_Learning.pdf → Python/
# Moved: Learn_Java_Fundamentals.pdf → Java/
# Moved: Introduction_to_Python_for_Science_and_E.pdf → Python/
# Moved: Mastering_Python_Programming_for_Beginne.pdf → Python/
# Moved: Ethical_Hacking_with_Python__2023_.pdf → Python/
# Moved: Active_Machine_Learning_with_Python.pdf → Python/
# Moved: Coding_for_kids_Python__2020_.pdf → Python/
# Moved: Python.pdf → Python/Moved: Python_Logging.pdf → Python/
#
# Moved: Using_Python_to_Develop_Analytics__Contr.pdf → Computer_Science/
# Moved: Data_Mining_with_Python__2024_.pdf → Python/
# Moved: Python_for_Probability__Statistics__and_.pdf → Computer_Science/
# Moved: Learn_OpenCV_with_Python_by_Examples.pdf → Python/
# Moved: Monte_Carlo_with_Python__2024_.pdf → Python/
# Moved: Introduction_to_Python_Programming.pdf → Python/
# Moved: Mastering_Python__2024_.pdf → Python/
# Moved: ScientificPythonLectures.pdf → Python/
# Moved: Adaptive_Machine_Learning_Algorithms_wit.pdf → Computer_Science/
# Moved: Computer_Networks__2023_.pdf → Network_Security/
# Moved: Python_200_Essential_Concepts_for_Beginn.pdf → Python/
# Moved: Python_Machine_Learning_Cookbook___Early.pdf → Python/
# Moved: The_cartoon_guide_to_statistics.pdf → Computer_Science/
# Moved: WAIC_and_WBIC_with_Python_Stan.pdf → Python/
# Moved: Python_for_Teenagers.pdf → Python/
# Moved: Learn_Python_Programming_Quickly.pdf → Python/
# Moved: Natural_Language_Processing_with_Python_.pdf → Python/
# Moved: IoT_enabled_Convolutional_Neural_Network.pdf → Network_Security/
# Moved: Mastering_the_Java_Virtual_Machine.pdf → Java/
# Moved: Spring_Security_in_Action.pdf → Network_Security/
# Moved: Advanced_Analytics_with_Power_BI_and_Exc.pdf → Computer_Science/
# Moved: Python_20Interviews.pdf → Python/
# Moved: A_Journey_to_Core_Python__datascienceM.pdf → Python/
# Moved: Python_Machine_Learning_Projects.pdf → Python/
# Moved: The_Mathematics_of_Machine_Learning__202.pdf → Computer_Science/
# Moved: Zero_Trust_Networks.pdf → Network_Security/
# Moved: Python_for_Tensorflow_Pocket_Primer.pdf → Python/
# Moved: Learn_Python_the_right_way.pdf → Python/
# Moved: Network_Architect_s_Handbook.pdf → Network_Security/
# Moved: IPv6_Network_Slicing.pdf → Network_Security/
# Moved: Mathematical_Logic_through_Python.pdf → Python/
# Moved: StatisticsMachineLearningPython.pdf → Computer_Science/
# Moved: Data_Analytics___Visualization_All_in_On.pdf → Computer_Science/
# Moved: Python_3_MCQ.pdf → Python/
# Moved: Better_Python_Code__2_.pdf → Python/
# Moved: Python_Machine_Learning__2024_.pdf → Python/
# Moved: Absolute_Beginner_s_Guide_to_Algorithms.pdf → Computer_Science/
# Moved: THE_PYTHON_APPLICATION_ARCHITECT_S_COOKB.pdf → Python/
# Moved: Python_for_Water_and_Environment.pdf → Python/
# Moved: M4_ML_theory_algorithms.pdf → Computer_Science/
# Moved: Python_Games_Development_using_Pygame.pdf → Python/
# Moved: Neural_Networks_and_Deep_Learning.pdf → Network_Security/
# Moved: ITS_303_Python_Programming_Realistic_Moc.pdf → Python/
# Moved: Mathematics_for_Machine_Learning.pdf → Computer_Science/
# Moved: Statistics_and_Data_Visualization_in_Cli.pdf → Computer_Science/
# Moved: Data_Communication_and_Computer_Networks.pdf → Network_Security/
# Moved: Python_AI_Programming.pdf → Python/
# Moved: Book__Discrete_Mathematics_and_Its_Appli.pdf → Computer_Science/
# Moved: Python_Machine_Learning__3_.pdf → Python/
# Moved: Advanced_Python_Automation.pdf → Python/
# Moved: The_Python_Automation_Cookbook.pdf → Python/
# Moved: Machine_Learning_Algorithms_for_Signal_a.pdf → Computer_Science/
# Moved: Python_Game_Development.pdf → Python/
# Moved: Neural_Network_Computer_Vision_with_Open.pdf → Network_Security/
# Moved: Javascript.pdf → Java/
# Moved: Math_Adventures_with_Python__2020_.pdf → Python/
# Moved: Statistics_Machine_Learning_Python.pdf → Computer_Science/
# Moved: Data_Structures___Algorithms_in_Go.pdf → Computer_Science/
# Moved: Building_Java_Programs__A_Back_to_Basics.pdf → Computer_Science/
# Moved: Python_Cookbook.pdf → Python/
# Moved: Python_Playground.pdf → Python/
# Moved: Think_Python.pdf → Python/
# Moved: Algorithms_and_Data_Structures_with_Pyth.pdf → Computer_Science/Moved: Head_First_Statistics.pdf → Computer_Science/
# Moved: Python_Graphics.pdf → Computer_Science/Moved: Neural_Network_Programming_with_Java.pdf → Java/
#
#
# Moved: JavaScript_Learn_Easily_and_Quickly.pdf → Java/
# Moved: Learning_Python_5th_Edition.pdf → Python/
# Moved: Statistics_Unplugged.pdf → Computer_Science/
# Moved: Deep_Reinforcement_Learning_with_Python_.pdf → Python/
# Moved: Cloud_Native_Software_Security_Handbook.pdf → Network_Security/
# Moved: Python_Cookbook__2024_.pdf → Python/
# Moved: Python_Programming_Basics.pdf → Computer_Science/
# Moved: Think_Python__2024_.pdf → Python/
# Moved: Head_First_Statistics_pdf___PDFDrive__.pdf → Computer_Science/
# Moved: Algorithms_for_image_processing_and_comp.pdf → Computer_Science/
# Moved: JavaScript__2_.pdf → Java/
# Moved: Numerical_Algorithms_Methods_for_Compute.pdf → Computer_Science/
# Moved: Python_Image_Processing_Cookbook.pdf → Python/
# Moved: Learn_Java_with_Projects.pdf → Java/
# Moved: Strengthening_Deep_Neural_Networks.pdf → Network_Security/
# Moved: Enhancing_IoT_Security.pdf → Network_Security/
# Moved: codeprogrammer_Scientific_Python_Lecture.pdf → Python/
# Moved: Python_Data_Analysis_and_Visualization__.pdf → Python/
# Moved: Python_Programming_for_Beginners_Crash_C.pdf → Python/
# Moved: Thoughtful_Machine_Learning_with_Python_.pdf → Python/
# Moved: HTML_and_CSS_Design_and_Build_Websites_J.pdf → Computer_Science/
# Moved: Practical_Java_Programming_with_ChatGPT_.pdf → Java/
# Moved: Java_8_to_21__2023_.pdf → Java/
# Moved: Object_Oriented_Programming_with_Python.pdf → Python/
# Moved: Python_Libraries_for_Finance.pdf → Python/
# Moved: luciano_ramalho_fluent_python_clear_conc.pdf → Python/
# Moved: Supervised_Machine_Learning_with_Python.pdf → Python/
# Moved: Essentials_of_Python_for_Artificial_Inte.pdf → Python/
# Moved: Computer_Basics_Absolute_Beginner_s_Guid.pdf → Computer_Science/
# Moved: Python_Data_Analytics__Data_Analysis_and.pdf → Computer_Science/
# Moved: Python_Programming_for_Beginners__2023_.pdf → Python/
# Moved: Time_Series_Forecasting_in_Python.pdf → Python/
# Moved: Hypermodern_Python_Tooling.pdf → Python/
# Moved: Practical_Statistics_for_Data_Scientists.pdf → Computer_Science/
# Moved: Java_Cookbook.pdf → Java/
# Moved: OpenAI_GPT_For_Python_Developers.pdf → Python/
# Moved: Python_Machine_Learning.pdf → Python/
# Moved: Machine_Learning_and_Big_Data_Analytics.pdf → Computer_Science/
# Moved: Python_Machine_Learning_Blueprints.pdf → Python/
# Moved: Text_Processing_with_JavaScript.pdf → Java/
# Moved: Essential_Guide_to_Python_for_all_levels.pdf → Python/
# Moved: Cybersecurity_All_in_One_For_Dummies.pdf → Network_Security/
# Moved: Python_Data_Cleaning_Cookbook.pdf → Python/
# Moved: Sams_Teach_Yourself_Python_in_24_Hours__.pdf → Python/
# Moved: Ultimate_Java_for_Data_Analytics_and_Mac.pdf → Computer_Science/
# Moved: Introduction_duction_to_Python_String_Ma.pdf → Python/
# Moved: pythondatasciencehandbook.pdf → Python/
# Moved: Java_Programming_Exercises__2024_.pdf → Java/
# Moved: OpenCV_Python_Tutorials_2017.pdf → Python/
# Moved: Machine_Learning_in_Python_for_everyone.pdf → Python/
# Moved: Python_Machine_Learning_Case_Studies.pdf → Python/
# Moved: Y__Daniel_Liang___Intro_to_Java_Programm.pdf → Java/
# Moved: Exploring_JavaScript__2024_.pdf → Java/
# Moved: Python_Data_Structures.pdf → Python/
# Moved: Python_Programming_and_SQL_Bible__2024_.pdf → Python/
# Moved: ScientificPythonLectures_simple.pdf → Python/
# Moved: Ultimate_Linux_Network_Security_for_Ente.pdf → Network_Security/
# Moved: Introduction_to_Algorithms__fourth_editi.pdf → Computer_Science/
# Moved: Pythonic_AI__2023_.pdf → Python/
# Moved: Java_Programming_Exercises__Volume_Two.pdf → Java/
# Moved: Opportunistic_Networks.pdf → Network_Security/
# Moved: Mastering_HTML_and_CSS_for_Modern_Develo.pdf → Computer_Science/
# Moved: Python_Machine_Learning_Cookbook.pdf → Python/
# Moved: datascienceM_Python_Programming_and_SQL.pdf → Python/
# Moved: Football_Analytics_with_Python___R.pdf → Computer_Science/
# Moved: Python_Data_Structures_and_Algorithms.pdf → Computer_Science/
# Moved: SQL_Basics.pdf → Computer_Science/
# Moved: Scientific_Computing_with_Python.pdf → Python/
# Moved: Ultimate_Neural_Network_Programming_with.pdf → Network_Security/
# Moved: Introduction_to_Ansible_Network_Automati.pdf → Network_Security/
# Moved: PythonNotesForProfessionals.pdf → Python/
# Moved: Mastering_Python_Algorithms__2024_.pdf → Computer_Science/
# Moved: Options_with_Python.pdf → Python/
# Moved: Python_Machine_Learning_Essentials.pdf → Python/
# Moved: Java_Persistence_with_NoSQL.pdf → Java/
# Moved: Foundations_of_Data_Science_with_Python.pdf → Python/
# Moved: Python_Data_Visualization_Essentials_Gui.pdf → Python/
# Moved: Sql_Basics_And_Advanced.pdf → Computer_Science/
# Moved: Starting_Out_with_Python.pdf → Python/
# Moved: Unpacking_Intermediate_JavaScript.pdf → Java/
# Moved: Introduction_to_Programming_in_Python.pdf → Python/
# Moved: Python_3.pdf → Python/
# Moved: Mastering_Python__2_.pdf → Python/
# Moved: Pass_The_Python_Interview.pdf → Python/
# Moved: Python_Machine_Learning_Sebastian_Raschk.pdf → Python/
# Moved: Keras_beyond_Basics_and_Next_Level_SQL.pdf → Computer_Science/
# Moved: Grokking_Algorithms_In_Python.pdf → Computer_Science/
# Moved: Python_Debugging_for_AI__Machine_Learnin.pdf → Python/
# Moved: sql_basics_cheat_sheet.pdf → Computer_Science/
# Moved: Starting_Out_With_Python__2022_.pdf → Python/
# Moved: Using_Stable_Diffusion_with_Python__2_.pdf → Python/Moved: Java_Coding_Problems.pdf → Java/
#
# Moved: Python_and_Tkinter_Programming.pdf → Python/
# Moved: Mathematical_Methods_using_Python.pdf → Python/
# Moved: Portable_Python_Projects.pdf → Python/
# Moved: Python_Made_Easy.pdf → Python/
# Moved: Python_Deep_Learning__2023_.pdf → Python/
# Moved: SQL_Cheat_Sheet_Basics___SELECT__INSERT_.pdf → Computer_Science/
# Moved: Statistics_for_Business_and_Economics.pdf → Computer_Science/
# Moved: Visual_Analytics_with_Tableau_.pdf → Computer_Science/
# Moved: Java_Coding_Problems__2_.pdf → Java/
# Moved: Python_Apps_on_Visual_Studio_Code.pdf → Python/
# Moved: Mathematics_and_Computer_Science__2023_.pdf → Computer_Science/
# Moved: Power_Electronics__Third_Edition_by_Cyri.pdf → Computer_Science/
# Moved: Python_Mastery.pdf → Python/
# Moved: Python_Essentials_1__2024_.pdf → Python/
# Moved: SQL_Cheat_Sheet_Basics___SELECT__INSERT__1.pdf → Computer_Science/
# Moved: Statistics_with_Julia.pdf → Computer_Science/
# Moved: Java_Cookbook___Problems_and_Solutions_f.pdf → Java/
# Moved: Python_Based_Data_Structures_and_Algorit.pdf → Python/
# Moved: Math_for_Programmers___3D_graphics__mach.pdf → Computer_Science/
# Moved: Python_Mastery_Made_Simple_for_Beginners.pdf → Python/
# Moved: Python_Essentials_You_Always_Wanted_to_K.pdf → Python/
# Moved: Text_Mining_with_Python.pdf → Python/
# Moved: Job_Ready_Python__2024_.pdf → Python/
# Moved: Python_Crashkurs__2024_.pdf → Python/
# Moved: MicroPython_for_the_Internet_of_Things.pdf → Python/
# Moved: Python_Numpy_for_Beginners_and_Python_St.pdf → Python/
# Moved: Python_for_Absolute_Beginners.pdf → Python/
# Moved: The_Pythonic_Way.pdf → Python/
# Moved: Larry_Wasserman_ALL_OF_Statistics.pdf → Computer_Science/
# Moved: Python_Data_Analytics___Third_Edition.pdf → Computer_Science/
# Moved: Natural_Language_Processing_with_Python.pdf → Python/
# Moved: Python_Packages.pdf → Python/
# Moved: Python_for_Data_Science_For_Dummies__202.pdf → Python/
# Moved: Ultimate_Java_for_Data_Analytics_and_ML.pdf → Computer_Science/
# Moved: Python_Data_Science_Handbook_Essential_T.pdf → Python/
# Moved: Numerical_Methods_in_Physics_with_Python.pdf → Computer_Science/
# Moved: Python_Pandas_and_Python_Loops_for_Begin.pdf → Python/
# Moved: Python_for_Engineers.pdf → Python/
# Moved: ULTIMATE_Python_Guide__2024_.pdf → Python/
# Moved: Python_Essentials_1.pdf → Python/
# Moved: Python_Pandas_Tutorial_For_Beginners.pdf → Python/
# Moved: Python_for_Everybody.pdf → Python/
# Moved: Using_Stable_Diffusion_with_Python.pdf → Python/
# Moved: Python_for_AI.pdf → Python/
# Moved: Python_Power.pdf → Python/
# Moved: Python_for_Geometric_Modeling.pdf → Python/
# Moved: Python_for_Chemists.pdf → Python/
# Moved: Python_Preparation_Practice_Exams_Questi.pdf → Python/
# Moved: Python_For_Large_Language_Models__2025_.pdf → Python/
# Moved: Python_for_DevOps.pdf → Python/
# Moved: Python_Programming.pdf → Python/
# Moved: Python_GUI_with_PyQt.pdf → Python/
# Moved: Python_Programming_Book.pdf → Python/
# Moved: Python_Internals_for_Developers__2022_.pdf → Python/
# Moved: Python_Programming_for_Beginners__2024_.pdf → Python/
# Moved: Python_in_Excel__2024_.pdf → Python/
# Moved: Python_Programming_Fundamentals__2024_.pdf → Python/
# Moved: Python_Machine_Learning__2_.pdf → Python/
# Moved: Python_Projects_with_API.pdf → Python/
# Moved: Python_Machine_Learning__4_.pdf → Python/
# Moved: Python_QuickStart_Guide__2024_.pdf → Python/
# Moved: Python_Programming_for_Students.pdf → Python/
# Moved: Python_Quick_Interview_Guide.pdf → Python/
# Moved: Python_Programming_Using_Problem_Solving.pdf → Python/
# Moved: Python_Real_World_Projects.pdf → Python/
# Moved: Python__.pdf → Python/
# Moved: Python_Real_World_Projects__DatascienceM.pdf → Python/
# Moved: Python___Deeper_Insights_into_Machine_Le.pdf → Python/
# Moved: Python_Scikit_and_Python_Booleans_for_Be.pdf → Python/
# Moved: Rapid_GUI_Programming_with_Python.pdf → Python/
# Moved: Python_Starter_Guide.pdf → Python/
# Moved: Python_Tkinter_35_Mini_Projects__2024_.pdf → Python/
# Moved: Python_Tkinter_Gui_Projects.pdf → Python/
# Moved: Python_Trader__2023_.pdf → Python/
# Moved: Python_Web_Applications_with_Flask.pdf → Python/
# Moved: python___.pdf → Python/
# Moved: Quantum_Computing_Algorithms.pdf → Computer_Science/
